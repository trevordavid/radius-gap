# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["font.size"] = 20
rcParams['figure.dpi'] = 100
rcParams["savefig.dpi"] = 300
rcParams["savefig.bbox"] = 'tight'

import seaborn as sns
sns.set_context("paper")
sns.set_style("ticks")

import numpy as np
import pandas as pd
import pickle

import os
import requests
from io import BytesIO
from io import StringIO

from astropy.table import Table
from astropy.table import join
from astropy.io import ascii
import astropy.constants as c

from scipy import interpolate
from sklearn import svm
from arviz import hpd

# Function to get NASA Exoplanet Archive catalogs 
# from Dan Foreman-Mackey (https://github.com/dfm/exopop)
def get_catalog(name, basepath="../data"):
    fn = os.path.join(basepath, "{0}.h5".format(name))
    if os.path.exists(fn):
        return pd.read_hdf(fn, name)
    if not os.path.exists(basepath):
        os.makedirs(basepath)
    print("Downloading {0}...".format(name))
    url = ("http://exoplanetarchive.ipac.caltech.edu/cgi-bin/nstedAPI/"
           "nph-nstedAPI?table={0}&select=*").format(name)
    r = requests.get(url)
    if r.status_code != requests.codes.ok:
        r.raise_for_status()
        
    fh = BytesIO(r.content)
    df = pd.read_csv(fh)
    df.to_hdf(fn, name, format="t")
    return df

#To track the provenance of different columns, we want a function to prepend an informative string to each column name.
#We will do this before merging tables to make tracking the information easier.
def prepend_dataframe_columns(df, prefix):
    df.columns = [prefix+col for col in df.columns]
    return 


#Suppressing astropy units warnings
import warnings
from astropy.utils.exceptions import AstropyWarning

warnings.filterwarnings('ignore', category=UserWarning, append=True)
warnings.simplefilter('ignore', category=AstropyWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

#Suppressing Pandas chained assignment warnings
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### CKS VII Sample (Fulton & Petigura 2018)
# As a starting point we will begin with the CKS VII sample. This includes some planets which were not contained in Kepler Q1-Q17 DR25, so it allows us to study a larger sample.

# %%
# To access the CKS tables via FTP from CDS uncomment below
# cks_st = Table.read("ftp://cdsarc.unistra.fr/ftp/J/AJ/156/264/table2.dat",
#                     readme="ftp://cdsarc.unistra.fr/ftp/J/AJ/156/264/ReadMe", 
#                     format='ascii.cds')

# cks_pl = Table.read("ftp://cdsarc.unistra.fr/ftp/J/AJ/156/264/table3.dat",
#                     readme="ftp://cdsarc.unistra.fr/ftp/J/AJ/156/264/ReadMe", 
#                     format='ascii.cds')

cks_st = Table.read("../data/Fulton2018_stellarradii_ajaae828t2_mrt.txt", format='ascii')
cks_pl = Table.read("../data/Fulton2018_planetradii_ajaae828t3_mrt.txt", format='ascii')

# In order to join the tables we need to reformat the KOI identifiers
cks_pl['KOI_star'] = np.array([(x.split(".")[0]) for x in cks_pl['KOI']])
cks_st.rename_column('KOI', 'KOI_star')

# Join the CKS tables
cks = join(cks_pl, cks_st, join_type='left', keys='KOI_star')
# Prepend a prefix to each column to help keep track of the provenance of the data
cks = cks.to_pandas()
prepend_dataframe_columns(cks, 'f18_')

# Create a column for the integer values of each KOI. This will be useful for merging later.
cks['f18_KOI_int'] = [int(koi.split("K")[1]) for koi in cks['f18_KOI_star']]

cks.head()
# Out:
#      f18_KOI     f18_P       f18_E_P       f18_e_P  f18_Rp/R*  f18_E_Rp/R*  \
# 0  K00001.01  2.470613  1.900000e-08  1.900000e-08   0.123851     0.000025
# 1  K00002.01  2.204735  3.800000e-08  3.800000e-08   0.075408     0.000008
# 2  K00006.01  1.334104  7.070000e-07  7.070000e-07   0.294016     0.103683
# 3  K00007.01  3.213669  1.122000e-06  1.122000e-06   0.024735     0.000141
# 4  K00008.01  1.160153  4.270000e-07  4.270000e-07   0.018559     0.000246
#
#    f18_e_Rp/R*  f18_Rp  f18_E_Rp  f18_e_Rp  ...  f18_e_rhoiso  f18_logAiso  \
# 0     0.000076  14.141     0.331     0.331  ...          0.04         9.74
# 1     0.000007  16.250     0.349     0.349  ...          0.00         9.25
# 2     0.209459  41.936    22.239    22.239  ...          0.03         9.32
# 3     0.000076   4.076     0.107     0.107  ...          0.02         9.78
# 4     0.001678   1.896     0.110     0.110  ...          0.05         9.18
#
#    f18_E_logAiso  f18_e_logAiso  f18_plxspec  f18_E_plxspec f18_e_plxspec  \
# 0           0.13           0.15        4.756          0.320         0.474
# 1           0.04           0.05        3.661          0.411         0.586
# 2           0.09           0.24        2.201          0.127         0.212
# 3           0.09           0.08        2.112          0.228         0.274
# 4           0.26           0.52        2.895          0.127         0.192
#
#    f18_r8  f18_RCF  f18_KOI_int
# 0   1.000   1.0102            1
# 1   1.001   1.0034            2
# 2   1.007   1.0006            6
# 3   1.000      NaN            7
# 4   1.001      NaN            8
#
# [5 rows x 48 columns]

# %% [markdown]
# ### CKS I (Petigura et al. 2017)
# For consistency with CKS VII, we will use the false positive designations adopted in Table 4 of CKS I, which themselves are based on a compilation of planet candidate dispositions from Morton et al. (2016), Mullaly et al. (2015), and the NASA Exoplanet Archive (as it was on Feb. 1, 2017).

# %%
p17 = Table.read('ftp://cdsarc.unistra.fr/ftp/J/AJ/154/107/table4.dat',
                 readme='ftp://cdsarc.unistra.fr/ftp/J/AJ/154/107/ReadMe',
                 format='ascii.cds')

p17 = p17.to_pandas()
#Munging
p17['Name'] = [x.replace('OI-', '') for x in p17['Name']]
p17 = p17.rename(columns={'Name':'KOI'})
prepend_dataframe_columns(p17, 'p17_')

p17.head()
# Out:
#      p17_KOI p17_Disp p17_M16 p17_M15 p17_NEA
# 0  K00001.01       CP      CP      CP      CP
# 1  K00002.01       CP      CP      CP      CP
# 2  K00003.01       CP      CP      CP      CP
# 3  K00006.01       FP      FP      FP      FP
# 4  K00007.01       CP      CP      CP      CP

# %% [markdown]
# ### Kepler Q1-Q17 DR25 table
# As a starting point we begin with the [Kepler Q1-Q17 DR 25 KOI Table](https://exoplanetarchive.ipac.caltech.edu/docs/PurposeOfKOITable.html#q1-q17_dr25) which is described in [Thompson et al. 2018](https://arxiv.org/abs/1710.06758)

# %%
dr25 = get_catalog('q1_q17_dr25_koi')
prepend_dataframe_columns(dr25, 'dr25_')
dr25.head()
# Out:
#    dr25_kepid dr25_kepoi_name dr25_kepler_name    dr25_ra  dr25_ra_err  \
# 0    10811496       K00753.01              NaN  297.00482          0.0
# 1    10848459       K00754.01              NaN  285.53461          0.0
# 2    10854555       K00755.01     Kepler-664 b  288.75488          0.0
# 3    10872983       K00756.01     Kepler-228 d  296.28613          0.0
# 4    10872983       K00756.02     Kepler-228 c  296.28613          0.0
#
#     dr25_ra_str   dr25_dec  dr25_dec_err  dr25_dec_str  dr25_koi_gmag  ...  \
# 0  19h48m01.16s  48.134129           0.0  +48d08m02.9s         15.943  ...
# 1  19h02m08.31s  48.285210           0.0  +48d17m06.8s         16.100  ...
# 2  19h15m01.17s  48.226200           0.0  +48d13m34.3s         16.015  ...
# 3  19h45m08.67s  48.224670           0.0  +48d13m28.8s         16.234  ...
# 4  19h45m08.67s  48.224670           0.0  +48d13m28.8s         16.234  ...
#
#    dr25_koi_fpflag_co  dr25_koi_fpflag_ec  dr25_koi_insol  \
# 0                   0                   0           39.30
# 1                   0                   0          891.96
# 2                   0                   0          926.16
# 3                   0                   0          114.81
# 4                   0                   0          427.65
#
#    dr25_koi_insol_err1  dr25_koi_insol_err2  dr25_koi_srho  \
# 0                31.04               -10.49        7.29555
# 1               668.95              -230.35        0.22080
# 2               874.33              -314.24        1.98635
# 3               112.85               -36.70        0.67324
# 4               420.33              -136.70        0.37377
#
#    dr25_koi_srho_err1  dr25_koi_srho_err2  dr25_koi_fittype  dr25_koi_score
# 0            35.03293            -2.75453           LS+MCMC             0.0
# 1             0.00917            -0.01837           LS+MCMC             0.0
# 2             2.71141            -1.74541           LS+MCMC             1.0
# 3             0.33286            -0.38858           LS+MCMC             1.0
# 4             0.74768            -0.26357           LS+MCMC             1.0
#
# [5 rows x 153 columns]

# %% [markdown]
# ### Kepler Stellar Data
# We will also want the [Kepler Stellar data table](https://exoplanetarchive.ipac.caltech.edu/docs/Kepler_completeness_reliability.html) for the noise properties of each planet host. Since this is a large table, we have extracted the only columns we want ahead of time and stored this in the data directory.

# %%
stlr = pd.read_csv('../data/Kepler-Q1-Q17-DR25-CDPP3.csv')
prepend_dataframe_columns(stlr, 'stlr_')
stlr.head()
# Out:
#    stlr_kepid  stlr_rrmscdpp03p0
# 0    10000785            445.410
# 1    10000797             80.767
# 2    10000800            226.348
# 3    10000823            181.468
# 4    10000827            124.834

# %% [markdown]
# ### Gaia Kepler Stellar Properties Catalog (Berger et al. 2020)

# %%
b20 = pd.read_parquet('../data/GKSPCPapTable2.parquet')
b20.head()
# Out:
#    b20_KIC  b20_iso_mass  b20_iso_mass_err1  b20_iso_mass_err2  b20_iso_teff  \
# 0   757076         1.396              0.179             -0.218        5052.2
# 1   757099         0.873              0.054             -0.039        5364.9
# 2   757137         1.669              0.309             -0.300        4628.7
# 3   757280         1.715              0.086             -0.089        6856.8
# 4   757450         0.914              0.062             -0.057        5301.2
#
#    b20_iso_teff_err1  b20_iso_teff_err2  b20_iso_logg  b20_iso_logg_err1  \
# 0              103.9              -86.6         3.373              0.067
# 1              102.7              -84.9         4.318              0.037
# 2               84.8              -76.2         2.388              0.083
# 3              144.4             -139.9         3.834              0.033
# 4              111.0             -103.1         4.432              0.045
#
#    b20_iso_logg_err2  ...  b20_iso_age_err2  b20_iso_dis  b20_iso_dis_err1  \
# 0             -0.081  ...             -0.73        651.5              22.6
# 1             -0.029  ...             -3.98        367.8               7.1
# 2             -0.086  ...             -0.58        568.4              12.2
# 3             -0.032  ...             -0.16        822.0              19.4
# 4             -0.044  ...             -5.15        829.6              24.0
#
#    b20_iso_dis_err2  b20_iso_avs  b20_iso_gof  b20_TAMS  b20_log10_iso_age  \
# 0             -21.6        0.371          1.0      2.69           9.392697
# 1              -6.9        0.340          1.0     17.18          10.181844
# 2             -11.6        0.344          1.0      1.66           9.178977
# 3             -21.0        0.496          1.0      1.62           9.093422
# 4             -23.4        0.465          1.0     16.10           9.975891
#
#    b20_E_log10_iso_age  b20_e_log10_iso_age
# 0             0.239760             0.152148
# 1             0.078228             0.131851
# 2             0.230956             0.210494
# 3             0.064941             0.059998
# 4             0.194957             0.341414
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Petigura 2020
# The radius valley is partially contaminated by planets with poorly determined radius ratios due to high impact parameters (grazing or near-grazing transits)...

# %%
url = "https://raw.githubusercontent.com/petigura/keprat/master/data/cksgaia-planets.csv"
s = requests.get(url).content
p20 = pd.read_csv(StringIO(s.decode('utf-8')))
p20['Rtau'] = p20.tau/p20.tau0
prepend_dataframe_columns(p20, 'p20_')

p20.head()
# Out:
#    p20_id_kic p20_id_starname  p20_id_kic.1  p20_id_koi p20_id_koicand  \
# 0      757450          K00889        757450       889.0      K00889.01
# 1     1026957          K00958       1026957       958.0      K00958.01
# 2     1718189          K00993       1718189       993.0      K00993.01
# 3     1718189          K00993       1718189       993.0      K00993.02
# 4     1718189          K00993       1718189       993.0      K00993.03
#
#   p20_id_kepler_name p20_koi_disposition  p20_koi_period  p20_koi_period_err1  \
# 0        Kepler-75 b           CONFIRMED        8.884923             0.000001
# 1                NaN   NOT DISPOSITIONED       21.761294             0.000011
# 2       Kepler-262 c           CONFIRMED       21.853679             0.000097
# 3       Kepler-262 b           CONFIRMED       13.060767             0.000092
# 4                NaN           CANDIDATE       86.723152             0.001814
#
#    p20_koi_period_err2  ...  p20_fgraz  p20_tau0   p20_tau  \
# 0            -0.000001  ...        0.0  4.019727  1.856715
# 1            -0.000011  ...        0.0  4.427408  1.204967
# 2            -0.000097  ...        0.0  4.914936  3.306574
# 3            -0.000092  ...        0.0  4.139989  3.093553
# 4            -0.001814  ...        0.0  7.781345  4.761139
#
#    p20_dr25_ror_v18_srad  p20_dr25_ror_v18_srad_err1  p20_dr25_ror_gdir_srad  \
# 0                    NaN                         NaN               11.802615
# 1                    NaN                         NaN                2.478217
# 2                    NaN                         NaN                1.551245
# 3                    NaN                         NaN                1.267332
# 4                    NaN                         NaN                1.257706
#
#    p20_dr25_ror_gdir_srad_err1  p20_v18_ror_gdir_srad  \
# 0                     0.412225                    NaN
# 1                     0.114768                    NaN
# 2                     0.081248                    NaN
# 3                     0.068661                    NaN
# 4                     0.094337                    NaN
#
#    p20_v18_ror_gdir_srad_err1  p20_Rtau
# 0                         NaN  0.461901
# 1                         NaN  0.272161
# 2                         NaN  0.672760
# 3                         NaN  0.747237
# 4                         NaN  0.611866
#
# [5 rows x 246 columns]

# %% [markdown]
# ### Gaia-Kepler cross-match catalog
# Megan Bedell performed a positional cross-match of the Kepler and Gaia DR2 catalogs. The results are hosted [here](https://gaia-kepler.fun/). We will use the 1 arcsec (smallest) search radius.

# %%
gaia = pd.read_parquet('../data/kepler_dr2_1arcsec.parquet')
prepend_dataframe_columns(gaia, "gaia_")
gaia.head()
# Out:
#       gaia_solution_id                 gaia_designation       gaia_source_id  \
# 0  1635721458409799680  b'Gaia DR2 2050233807328471424'  2050233807328471424
# 1  1635721458409799680  b'Gaia DR2 2050233601176543104'  2050233601176543104
# 2  1635721458409799680  b'Gaia DR2 2050230543159814656'  2050230543159814656
# 3  1635721458409799680  b'Gaia DR2 2050230611879323904'  2050230611879323904
# 4  1635721458409799680  b'Gaia DR2 2050231848829944320'  2050231848829944320
#
#    gaia_random_index  gaia_gaia_ref_epoch     gaia_ra  gaia_ra_error  \
# 0          689405501               2015.5  291.038681       0.035878
# 1          447382505               2015.5  291.043057       0.019919
# 2         1004823384               2015.5  291.055892       0.019394
# 3         1253666653               2015.5  291.095373       0.016886
# 4          298032508               2015.5  291.137620       0.019560
#
#     gaia_dec  gaia_dec_error  gaia_parallax  ...  gaia_mass_err2  \
# 0  36.598031        0.047832       1.493916  ...          -0.475
# 1  36.593767        0.027553       2.678194  ...          -0.233
# 2  36.559886        0.026621       1.723413  ...          -0.947
# 3  36.564903        0.022993       1.183652  ...          -0.157
# 4  36.577344        0.025196       1.168913  ...          -0.040
#
#    gaia_prov_sec  gaia_nconfp  gaia_nkoi  gaia_ntce  gaia_jmag  gaia_hmag  \
# 0        b'DSEP'            0          0          0     10.126      9.667
# 1        b'DSEP'            0          0          1     11.656     11.193
# 2        b'DSEP'            0          0          0      7.467      6.853
# 3        b'DSEP'            0          0          0     10.852     10.662
# 4        b'DSEP'            1          1          1     13.665     13.262
#
#    gaia_kmag  gaia_planet?  gaia_kepler_gaia_ang_dist
# 0      9.559       b'none'                   0.156160
# 1     11.094       b'none'                   0.128262
# 2      6.722       b'none'                   0.146787
# 3     10.627       b'none'                   0.116420
# 4     13.118       b'conf'                   0.114502
#
# [5 rows x 134 columns]

# %% [markdown]
# ### Gaia DR2 RUWE values
# I queried the Gaia archive for RUWE values for the Gaia DR2-Kepler cross-match catalog above.

# %%
ruwe = pd.read_parquet('../data/kepler_dr2_1arcsec_ruwe.parquet')
ruwe.head()
# Out:
#    d20_kepid        d20_source_id  d20_ruwe  d20_koi
# 0     757076  2050233807328471424  0.946665      NaN
# 1     757099  2050233601176543104  2.172801      NaN
# 2     757137  2050230543159814656  0.912556      NaN
# 3     757280  2050230611879323904  0.870375      NaN
# 4     757450  2050231848829944320  1.030048    889.0

# %% [markdown]
# ### Kinematic ages from [Lu et al. 2021](https://arxiv.org/abs/2102.01772)

# %%
kin = pickle.load(open( "../data/KinageAllKepler.pkl", "rb" ))
kin_base = pd.DataFrame(kin)
kin = kin[kin.columns[-20:]] #Select only the columns of interest
prepend_dataframe_columns(kin, 'l20_')

# %% [markdown]
# ### Rotation periods

# %%
##############################################################
# Rotation periods
rot = pd.read_csv('../data/Young_planets_CKOI_20200324.csv')
rot = pd.DataFrame({'Prot_KIC': rot.KIC,
                    'Prot_flag': rot.Prot_flag,
                    'Prot_adopted': rot.Prot_adopted,
                    'Prot_ANG18': rot.Prot_ANG18,
                    'Prot_MAZ15': rot.Prot_MAZ15,
                    'Prot_D20': rot.Prot_D20,
                    'Prot_MCQ13': rot.Prot_MCQ13,
                    'Prot_WAL13': rot.Prot_WAL13})

rot['Prot'] = np.nan*np.ones(len(rot))

for ref in ['a18', 'd20', 'm13', 'm15']:
    _mask = rot['Prot_adopted'] == ref
    
    if ref=='a18':
        rot['Prot'][_mask] = rot['Prot_ANG18'][_mask]
    elif ref=='d20':
        rot['Prot'][_mask] = rot['Prot_D20'][_mask]
    elif ref=='M13':
        rot['Prot'][_mask] = rot['Prot_MCQ13'][_mask]
    elif ref=='M15':
        rot['Prot'][_mask] = rot['Prot_MAZ15'][_mask]

# %% [markdown]
# ### Rotation periods
# Several authors have measured rotation periods for the Kepler sample, and specifically for KOIs. We compile some of the largest studies here.

# %% [markdown]
# ### [Angus et al. 2018](https://ui.adsabs.harvard.edu/abs/2018MNRAS.474.2094A/abstract) rotation period catalog

# %%
a18 = pd.read_csv("../data/Angus2018_koi_periods_nohead.csv")
prepend_dataframe_columns(a18, "a18_")
a18.head()
# Out:
#    a18_Index  a18_KOI  a18_feh  a18_feh_errm  a18_feh_errp  a18_logg  \
# 0          0        1    -0.12        -0.280         0.330     4.609
# 1          1        2    -0.15        -0.100         0.100     4.455
# 2          2        3     0.26        -0.080         0.080     4.021
# 3          3        6    -0.04        -0.160         0.120     4.169
# 4          4        7     0.44        -0.101         0.101     4.081
#
#    a18_logg_errm  a18_logg_errp  a18_period  a18_period_errm  a18_period_errp  \
# 0         -0.106          0.027   24.848729         5.996906        23.240003
# 1         -0.025          0.025   19.595792         3.779434         3.951450
# 2         -0.011          0.011   28.159582         0.193655         2.656332
# 3         -0.048          0.055   22.765454        15.400891         3.123556
# 4         -0.014          0.014   25.310087         1.685785         1.968450
#
#    a18_teff  a18_teff_errm  a18_teff_errp
# 0    5126.0         -138.0          160.0
# 1    5850.0          -50.0           50.0
# 2    6350.0          -80.0           80.0
# 3    6225.0         -158.0          114.0
# 4    5543.0          -79.0           79.0

# %% [markdown]
# ### [Mazeh et al. 2015](https://ui.adsabs.harvard.edu/abs/2015ApJ...801....3M/abstract) rotation period catalog

# %%
m15 = Table.read("ftp://cdsarc.unistra.fr/ftp/J/ApJ/801/3/table1.dat",
                readme="ftp://cdsarc.unistra.fr/ftp/J/ApJ/801/3/ReadMe", format="ascii.cds")
m15 = m15.to_pandas()
prepend_dataframe_columns(m15, "m15_")
m15.head()
# Out:
#    m15_KOI   m15_KIC  m15_Teff  m15_log(g)  m15_Prot  m15_e_Prot  m15_Rvar  \
# 0        1  11446443      5713       4.143     70.55       16.47     445.0
# 1        2  10666592      6264       3.790     70.69        6.80     919.0
# 2        3  10748390      4766       4.590     29.31        0.49   12246.0
# 3        5   8554498      5861       4.170     37.23        4.18     237.0
# 4       10   6922244      6213       4.170     82.12       16.05    1245.0
#
#     m15_LPH     m15_w  m15_D  m15_N  m15_C  m15_G  m15_T  m15_F  m15_R  \
# 0  0.362359  0.000000      0      0      0      0      0      0      0
# 1  0.542156  0.000000      0      1      0      0      0      0      0
# 2  0.607229  0.431926      0      1      0      0      0      0      0
# 3  0.082306  0.000000      0      0      0      0      0      0      0
# 4  0.350827  0.000000      0      0      0      0      0      0      0
#
#    m15_M1  m15_M2
# 0       1       0
# 1       1       0
# 2       0       0
# 3       1       0
# 4       1       0

# %% [markdown]
# ### [McQuillan et al. 2013](https://ui.adsabs.harvard.edu/abs/2013ApJ...775L..11M/abstract) rotation period catalog

# %%
m13 = Table.read("ftp://cdsarc.unistra.fr/ftp/J/ApJ/775/L11/table1.dat", 
                readme="ftp://cdsarc.unistra.fr/ftp/J/ApJ/775/L11/ReadMe", format="ascii.cds")
m13 = m13.to_pandas()
prepend_dataframe_columns(m13, "m13_")
m13.head()
# Out:
#    m13_KOI   m13_KIC  m13_Teff  m13_log(g)  m13_Rp m13_---  m13_Porb  \
# 0        3  10748390      4766        4.59    4.68     NaN     4.888
# 1       12   5812701      6419        4.26   13.40     NaN    17.855
# 2       41   6521045      5909        4.28    1.24     NaN     6.887
# 3       42   8866102      6170        4.10    2.71     NaN    17.834
# 4       44   8845026      6250        3.50    9.61     NaN    66.468
#
#    m13_Prot  m13_e_Prot  m13_Rvar m13_Flag
# 0    29.472       0.134     11.75        N
# 1     1.245       0.124      0.78      NaN
# 2    24.988       2.192      0.39      NaN
# 3    20.850       0.007      1.12      NaN
# 4     3.792       0.907      1.16      NaN

# %% [markdown]
# ### [Walkowicz & Basri 2013](https://ui.adsabs.harvard.edu/abs/2013MNRAS.436.1883W/abstract) rotation period catalog

# %%
w13 = Table.read("ftp://cdsarc.unistra.fr/ftp/J/MNRAS/436/1883/table2.dat",
                 readme="ftp://cdsarc.unistra.fr/ftp/J/MNRAS/436/1883/ReadMe",
                 format="ascii.cds")
w13 = w13.to_pandas()
prepend_dataframe_columns(w13, "w13_")
w13.head()
# Out:
#     w13_KIC  w13_KOI  w13_Teff  w13_logg  w13_logVar  w13_Per  w13_e_Per  \
# 0   5903312        8    5783.0      4.29        0.43    13.88       3.28
# 1   7684873       14    7906.0      3.93       -0.07     5.83       7.32
# 2   7255336       19       NaN    -99.00        0.15     2.43       2.40
# 3  10125352       21    6122.0      4.22        0.29     4.59       1.03
# 4   9071386       23    6324.0      4.27        0.32     4.69       9.07
#
#    w13_Ro  w13_B-V  w13_Age
# 0    1.12     0.66     1.46
# 1  -99.00     0.24   -99.00
# 2    0.13     0.78     0.05
# 3    0.67     0.56     0.35
# 4    0.93     0.52     0.62

# %% [markdown]
# ### Lithium abundances for the CKS sample ([Berger et al. 2018](https://ui.adsabs.harvard.edu/abs/2018ApJ...855..115B/abstract))

# %%
b18 = Table.read("https://cdsarc.unistra.fr/ftp/J/ApJ/855/115/table1.dat",
                 readme="https://cdsarc.unistra.fr/ftp/J/ApJ/855/115/ReadMe",
                 format="ascii.cds")

b18 = b18.to_pandas()
prepend_dataframe_columns(b18, "b18_")

b18_tb2 = Table.read("https://cdsarc.unistra.fr/ftp/J/ApJ/855/115/table2.dat",
                 readme="https://cdsarc.unistra.fr/ftp/J/ApJ/855/115/ReadMe",
                 format="ascii.cds")

b18_tb2 = b18_tb2.to_pandas()
prepend_dataframe_columns(b18_tb2, "b18_tb2_")

b18.head()
# Out:
#     b18_Obs    b18_Date  b18_KOI  b18_Kpmag  b18_S/N  b18_Teff  b18_logg  \
# 0  j122.742  2011-06-16        1      11.34       39      5819      4.40
# 1   j122.92  2011-06-13        2      10.46       39      6449      4.13
# 2   j122.81  2011-06-13        3       9.17       41      4864      4.50
# 3  j70.1247  2009-06-05        6      12.16      119      6348      4.36
# 4   j74.509  2009-07-31        7      12.21      126      5827      4.09
#
#    b18_[Fe/H]  b18_Vt  b18_EW(Li)  b18_e_EW(Li)  b18_A(Li)  b18_e_A(Li)
# 0        0.01    1.04        85.5           7.9       2.62         0.08
# 1        0.20    1.77        82.9           7.3       3.11         0.07
# 2        0.33    0.54         4.2           5.1      -0.40          NaN
# 3        0.04    1.58        15.4           2.2       2.16         0.08
# 4        0.18    1.17        54.0           2.1       2.36         0.06

# %% [markdown]
# ### Activity indicators from LAMOST ([Frasca et al. 2016](https://ui.adsabs.harvard.edu/abs/2016A%26A...594A..39F/abstract))
#
# Note these are not used in the publication

# %%
# f16 = Table.read("https://cdsarc.unistra.fr/ftp/J/A+A/594/A39/tablea4.dat",
#                  readme="https://cdsarc.unistra.fr/ftp/J/A+A/594/A39/ReadMe",
#                  format="ascii.cds")
# f16 = f16.to_pandas()
# prepend_dataframe_columns(f16, 'f16_')
# f16.head()

# %% [markdown]
# ### GALEX-Kepler cross-match (Olmedo et al. 2015)

# %%
# Olmedo et al. 2015 GALEX Kepler 
# o15 = Table.read("../data/olmedo2015/table4.dat",
#                  readme="../data/olmedo2015/ReadMe",
#                  format="ascii.cds")

# o15 = o15.to_pandas()
# prepend_dataframe_columns(o15, 'o15_')

# %% [markdown]
# ### Silva-Aguirre et al. 2015

# %%
# Silva-Aguirre et al. 2015 Asteroseismic Sample
s15 = Table.read("ftp://cdsarc.unistra.fr/ftp/J/MNRAS/452/2127/table3.dat",
                 readme="ftp://cdsarc.unistra.fr/ftp/J/MNRAS/452/2127/ReadMe",
                 format="ascii.cds")

s15 = s15.to_pandas()
prepend_dataframe_columns(s15, 's15_')

# %% [markdown]
# ### Merging tables
# Note this cell should only be run once

# %%
cks = cks.merge(p17, how='left', left_on='f18_KOI', right_on='p17_KOI')
cks = cks.merge(dr25, how='left', left_on='f18_KOI', right_on='dr25_kepoi_name')
cks = cks.merge(stlr, how='left', left_on='dr25_kepid', right_on='stlr_kepid')
cks = cks.merge(gaia, how='left', left_on='dr25_kepid', right_on='gaia_kepid')
cks = cks.merge(p20, how='left', left_on='dr25_kepoi_name', right_on='p20_id_koicand')
cks = cks.merge(b20, how='left', left_on='dr25_kepid', right_on='b20_KIC')
cks = cks.merge(ruwe, how='left', left_on='dr25_kepid', right_on='d20_kepid')
cks = cks.merge(kin, how='left', left_on='dr25_kepid', right_on='l20_KID')
cks = cks.merge(rot, how='left', left_on='dr25_kepid', right_on='Prot_KIC')

cks = cks.merge(a18, how='left', left_on='p20_id_koi', right_on='a18_KOI')
cks = cks.merge(m15, how='left', left_on='dr25_kepid', right_on='m15_KIC')
cks = cks.merge(m13, how='left', left_on='dr25_kepid', right_on='m13_KIC')
cks = cks.merge(w13, how='left', left_on='dr25_kepid', right_on='w13_KIC')
cks = cks.merge(b18, how='left', left_on='f18_KOI_int', right_on='b18_KOI')
cks = cks.merge(b18_tb2, how='left', left_on='f18_KOI_int', right_on='b18_tb2_KOI')
cks = cks.merge(s15, how='left', left_on='dr25_kepid', right_on='s15_KIC')

#cks = cks.merge(f16, how='left', left_on='dr25_kepid', right_on='f16_KIC')
#Note, merging with the Olmedo et al. 2015 catalog takes a long time
#cks = cks.merge(o15, how='left', left_on='dr25_kepid', right_on='o15_KIC')

cks_base = pd.DataFrame(cks)

# %%
for col in cks.columns:
    print(col)
# Out:
# f18_KOI
# f18_P
# f18_E_P
# f18_e_P
# f18_Rp/R*
# f18_E_Rp/R*
# f18_e_Rp/R*
# f18_Rp
# f18_E_Rp
# f18_e_Rp
# f18_a
# f18_E_a
# f18_e_a
# f18_Sinc
# f18_E_Sinc
# f18_e_Sinc
# f18_KOI_star
# f18_Teff
# f18_E_Teff
# f18_e_Teff
# f18_[Fe/H]
# f18_E_[Fe/H]
# f18_e_[Fe/H]
# f18_Ksmag
# f18_e_Ksmag
# f18_plx
# f18_e_plx
# f18_R
# f18_E_R
# f18_e_R
# f18_Miso
# f18_E_Miso
# f18_e_Miso
# f18_Riso
# f18_E_Riso
# f18_e_Riso
# f18_rhoiso
# f18_E_rhoiso
# f18_e_rhoiso
# f18_logAiso
# f18_E_logAiso
# f18_e_logAiso
# f18_plxspec
# f18_E_plxspec
# f18_e_plxspec
# f18_r8
# f18_RCF
# f18_KOI_int
# p17_KOI
# p17_Disp
# p17_M16
# p17_M15
# p17_NEA
# dr25_kepid
# dr25_kepoi_name
# dr25_kepler_name
# dr25_ra
# dr25_ra_err
# dr25_ra_str
# dr25_dec
# dr25_dec_err
# dr25_dec_str
# dr25_koi_gmag
# dr25_koi_gmag_err
# dr25_koi_rmag
# dr25_koi_rmag_err
# dr25_koi_imag
# dr25_koi_imag_err
# dr25_koi_zmag
# dr25_koi_zmag_err
# dr25_koi_jmag
# dr25_koi_jmag_err
# dr25_koi_hmag
# dr25_koi_hmag_err
# dr25_koi_kmag
# dr25_koi_kmag_err
# dr25_koi_kepmag
# dr25_koi_kepmag_err
# dr25_koi_delivname
# dr25_koi_vet_stat
# dr25_koi_quarters
# dr25_koi_disposition
# dr25_koi_pdisposition
# dr25_koi_count
# dr25_koi_num_transits
# dr25_koi_max_sngle_ev
# dr25_koi_max_mult_ev
# dr25_koi_bin_oedp_sig
# dr25_koi_limbdark_mod
# dr25_koi_ldm_coeff4
# dr25_koi_ldm_coeff3
# dr25_koi_ldm_coeff2
# dr25_koi_ldm_coeff1
# dr25_koi_trans_mod
# dr25_koi_model_snr
# dr25_koi_model_dof
# dr25_koi_model_chisq
# dr25_koi_time0bk
# dr25_koi_time0bk_err1
# dr25_koi_time0bk_err2
# dr25_koi_eccen
# dr25_koi_eccen_err1
# dr25_koi_eccen_err2
# dr25_koi_longp
# dr25_koi_longp_err1
# dr25_koi_longp_err2
# dr25_koi_prad
# dr25_koi_prad_err1
# dr25_koi_prad_err2
# dr25_koi_sma
# dr25_koi_sma_err1
# dr25_koi_sma_err2
# dr25_koi_impact
# dr25_koi_impact_err1
# dr25_koi_impact_err2
# dr25_koi_duration
# dr25_koi_duration_err1
# dr25_koi_duration_err2
# dr25_koi_ingress
# dr25_koi_ingress_err1
# dr25_koi_ingress_err2
# dr25_koi_depth
# dr25_koi_depth_err1
# dr25_koi_depth_err2
# dr25_koi_period
# dr25_koi_period_err1
# dr25_koi_period_err2
# dr25_koi_ror
# dr25_koi_ror_err1
# dr25_koi_ror_err2
# dr25_koi_dor
# dr25_koi_dor_err1
# dr25_koi_dor_err2
# dr25_koi_incl
# dr25_koi_incl_err1
# dr25_koi_incl_err2
# dr25_koi_teq
# dr25_koi_teq_err1
# dr25_koi_teq_err2
# dr25_koi_steff
# dr25_koi_steff_err1
# dr25_koi_steff_err2
# dr25_koi_slogg
# dr25_koi_slogg_err1
# dr25_koi_slogg_err2
# dr25_koi_smet
# dr25_koi_smet_err1
# dr25_koi_smet_err2
# dr25_koi_srad
# dr25_koi_srad_err1
# dr25_koi_srad_err2
# dr25_koi_smass
# dr25_koi_smass_err1
# dr25_koi_smass_err2
# dr25_koi_sage
# dr25_koi_sage_err1
# dr25_koi_sage_err2
# dr25_koi_sparprov
# dr25_koi_fwm_stat_sig
# dr25_koi_fwm_sra
# dr25_koi_fwm_sra_err
# dr25_koi_fwm_sdec
# dr25_koi_fwm_sdec_err
# dr25_koi_fwm_srao
# dr25_koi_fwm_srao_err
# dr25_koi_fwm_sdeco
# dr25_koi_fwm_sdeco_err
# dr25_koi_fwm_prao
# dr25_koi_fwm_prao_err
# dr25_koi_fwm_pdeco
# dr25_koi_fwm_pdeco_err
# dr25_koi_dicco_mra
# dr25_koi_dicco_mra_err
# dr25_koi_dicco_mdec
# dr25_koi_dicco_mdec_err
# dr25_koi_dicco_msky
# dr25_koi_dicco_msky_err
# dr25_koi_dikco_mra
# dr25_koi_dikco_mra_err
# dr25_koi_dikco_mdec
# dr25_koi_dikco_mdec_err
# dr25_koi_dikco_msky
# dr25_koi_dikco_msky_err
# dr25_koi_comment
# dr25_koi_vet_date
# dr25_koi_tce_plnt_num
# dr25_koi_tce_delivname
# dr25_koi_datalink_dvs
# dr25_koi_disp_prov
# dr25_koi_parm_prov
# dr25_koi_time0
# dr25_koi_time0_err1
# dr25_koi_time0_err2
# dr25_koi_datalink_dvr
# dr25_koi_fpflag_nt
# dr25_koi_fpflag_ss
# dr25_koi_fpflag_co
# dr25_koi_fpflag_ec
# dr25_koi_insol
# dr25_koi_insol_err1
# dr25_koi_insol_err2
# dr25_koi_srho
# dr25_koi_srho_err1
# dr25_koi_srho_err2
# dr25_koi_fittype
# dr25_koi_score
# stlr_kepid
# stlr_rrmscdpp03p0
# gaia_solution_id
# gaia_designation
# gaia_source_id
# gaia_random_index
# gaia_gaia_ref_epoch
# gaia_ra
# gaia_ra_error
# gaia_dec
# gaia_dec_error
# gaia_parallax
# gaia_parallax_error
# gaia_parallax_over_error
# gaia_pmra
# gaia_pmra_error
# gaia_pmdec
# gaia_pmdec_error
# gaia_ra_dec_corr
# gaia_ra_parallax_corr
# gaia_ra_pmra_corr
# gaia_ra_pmdec_corr
# gaia_dec_parallax_corr
# gaia_dec_pmra_corr
# gaia_dec_pmdec_corr
# gaia_parallax_pmra_corr
# gaia_parallax_pmdec_corr
# gaia_pmra_pmdec_corr
# gaia_astrometric_n_obs_al
# gaia_astrometric_n_obs_ac
# gaia_astrometric_n_good_obs_al
# gaia_astrometric_n_bad_obs_al
# gaia_astrometric_gof_al
# gaia_astrometric_chi2_al
# gaia_astrometric_excess_noise
# gaia_astrometric_excess_noise_sig
# gaia_astrometric_params_solved
# gaia_astrometric_primary_flag
# gaia_astrometric_weight_al
# gaia_astrometric_pseudo_colour
# gaia_astrometric_pseudo_colour_error
# gaia_mean_varpi_factor_al
# gaia_astrometric_matched_observations
# gaia_visibility_periods_used
# gaia_astrometric_sigma5d_max
# gaia_frame_rotator_object_type
# gaia_matched_observations
# gaia_duplicated_source
# gaia_phot_g_n_obs
# gaia_phot_g_mean_flux
# gaia_phot_g_mean_flux_error
# gaia_phot_g_mean_flux_over_error
# gaia_phot_g_mean_mag
# gaia_phot_bp_n_obs
# gaia_phot_bp_mean_flux
# gaia_phot_bp_mean_flux_error
# gaia_phot_bp_mean_flux_over_error
# gaia_phot_bp_mean_mag
# gaia_phot_rp_n_obs
# gaia_phot_rp_mean_flux
# gaia_phot_rp_mean_flux_error
# gaia_phot_rp_mean_flux_over_error
# gaia_phot_rp_mean_mag
# gaia_phot_bp_rp_excess_factor
# gaia_phot_proc_mode
# gaia_bp_rp
# gaia_bp_g
# gaia_g_rp
# gaia_radial_velocity
# gaia_radial_velocity_error
# gaia_rv_nb_transits
# gaia_rv_template_teff
# gaia_rv_template_logg
# gaia_rv_template_fe_h
# gaia_phot_variable_flag
# gaia_l
# gaia_b
# gaia_ecl_lon
# gaia_ecl_lat
# gaia_priam_flags
# gaia_teff_val
# gaia_teff_percentile_lower
# gaia_teff_percentile_upper
# gaia_a_g_val
# gaia_a_g_percentile_lower
# gaia_a_g_percentile_upper
# gaia_e_bp_min_rp_val
# gaia_e_bp_min_rp_percentile_lower
# gaia_e_bp_min_rp_percentile_upper
# gaia_flame_flags
# gaia_radius_val
# gaia_radius_percentile_lower
# gaia_radius_percentile_upper
# gaia_lum_val
# gaia_lum_percentile_lower
# gaia_lum_percentile_upper
# gaia_datalink_url
# gaia_epoch_photometry_url
# gaia_kepid
# gaia_ra_kic
# gaia_dec_kic
# gaia_r_est
# gaia_r_lo
# gaia_r_hi
# gaia_r_length_prior
# gaia_r_result_flag
# gaia_r_modality_flag
# gaia_tm_designation
# gaia_kepmag
# gaia_teff
# gaia_teff_err1
# gaia_teff_err2
# gaia_teff_prov
# gaia_logg
# gaia_logg_err1
# gaia_logg_err2
# gaia_logg_prov
# gaia_feh
# gaia_feh_err1
# gaia_feh_err2
# gaia_feh_prov
# gaia_radius
# gaia_radius_err1
# gaia_radius_err2
# gaia_mass
# gaia_mass_err1
# gaia_mass_err2
# gaia_prov_sec
# gaia_nconfp
# gaia_nkoi
# gaia_ntce
# gaia_jmag
# gaia_hmag
# gaia_kmag
# gaia_planet?
# gaia_kepler_gaia_ang_dist
# p20_id_kic
# p20_id_starname
# p20_id_kic.1
# p20_id_koi
# p20_id_koicand
# p20_id_kepler_name
# p20_koi_disposition
# p20_koi_period
# p20_koi_period_err1
# p20_koi_period_err2
# p20_koi_time0
# p20_koi_time0_err1
# p20_koi_time0_err2
# p20_koi_impact
# p20_koi_impact_err1
# p20_koi_impact_err2
# p20_koi_duration
# p20_koi_duration_err1
# p20_koi_duration_err2
# p20_koi_ingress
# p20_koi_ingress_err1
# p20_koi_ingress_err2
# p20_koi_depth
# p20_koi_depth_err1
# p20_koi_depth_err2
# p20_koi_ror
# p20_koi_ror_err1
# p20_koi_ror_err2
# p20_koi_srho
# p20_koi_srho_err1
# p20_koi_srho_err2
# p20_koi_prad
# p20_koi_prad_err1
# p20_koi_prad_err2
# p20_koi_sma
# p20_koi_sma_err1
# p20_koi_sma_err2
# p20_koi_teq
# p20_koi_teq_err1
# p20_koi_teq_err2
# p20_koi_insol
# p20_koi_insol_err1
# p20_koi_insol_err2
# p20_koi_dor
# p20_koi_dor_err1
# p20_koi_dor_err2
# p20_koi_max_mult_ev
# p20_koi_model_snr
# p20_koi_count
# p20_koi_num_transits
# p20_koi_steff
# p20_koi_steff_err1
# p20_koi_steff_err2
# p20_koi_slogg
# p20_koi_slogg_err1
# p20_koi_slogg_err2
# p20_koi_smet
# p20_koi_smet_err1
# p20_koi_smet_err2
# p20_koi_srad
# p20_koi_srad_err1
# p20_koi_srad_err2
# p20_koi_smass
# p20_koi_smass_err1
# p20_koi_smass_err2
# p20_koi_sage
# p20_koi_sage_err1
# p20_koi_sage_err2
# p20_koi_sparprov
# p20_kic_kepmag
# p20_kic_jmag
# p20_kic_hmag
# p20_kic_kmag
# p20_cks_fp
# p20_cks_steff
# p20_cks_steff_err1
# p20_cks_steff_err2
# p20_cks_slogg
# p20_cks_slogg_err1
# p20_cks_slogg_err2
# p20_cks_smet
# p20_cks_smet_err1
# p20_cks_smet_err2
# p20_cks_svsini
# p20_cks_svsini_err1
# p20_cks_svsini_err2
# p20_iso_steff
# p20_iso_steff_err1
# p20_iso_steff_err2
# p20_iso_slogg
# p20_iso_slogg_err1
# p20_iso_slogg_err2
# p20_iso_smet
# p20_iso_smet_err1
# p20_iso_smet_err2
# p20_iso_srad
# p20_iso_srad_err1
# p20_iso_srad_err2
# p20_iso_smass
# p20_iso_smass_err1
# p20_iso_smass_err2
# p20_iso_sage
# p20_iso_sage_err1
# p20_iso_sage_err2
# p20_iso_slogage
# p20_iso_slogage_err1
# p20_iso_slogage_err2
# p20_iso_sparallax
# p20_iso_sparallax_err1
# p20_iso_sparallax_err2
# p20_iso_prad
# p20_iso_prad_err1
# p20_iso_prad_err2
# p20_iso_sma
# p20_iso_sma_err1
# p20_iso_sma_err2
# p20_iso_insol
# p20_iso_insol_err1
# p20_iso_insol_err2
# p20_iso_teq
# p20_iso_teq_err1
# p20_iso_teq_err2
# p20_gaia2_angdist
# p20_gaia2_ra
# p20_gaia2_dec
# p20_gaia2_sparallax
# p20_gaia2_sparallax_err
# p20_gaia2_gflux
# p20_gaia2_gflux_err
# p20_gaia2_n_1arcsec
# p20_gaia2_n_8arcsec
# p20_gaia2_gflux_ratio
# p20_gaia2_gmag
# p20_gaia2_srad
# p20_gaia2_srad_err1
# p20_gaia2_srad_err2
# p20_gaia2_steff
# p20_gaia2_steff_err1
# p20_gaia2_steff_err2
# p20_m17_kmag
# p20_m17_kmag_err
# p20_gdir_srad
# p20_gdir_srad_err1
# p20_gdir_srad_err2
# p20_giso_smass
# p20_giso_smass_err2
# p20_giso_smass_err1
# p20_giso_srad
# p20_giso_srad_err1
# p20_giso_srad_err2
# p20_giso_srho
# p20_giso_srho_err1
# p20_giso_srho_err2
# p20_giso_sage
# p20_giso_sage_err1
# p20_giso_sage_err2
# p20_giso_slogage
# p20_giso_slogage_err1
# p20_giso_slogage_err2
# p20_gdir_prad
# p20_gdir_prad_err1
# p20_gdir_prad_err2
# p20_giso_sma
# p20_giso_sma_err1
# p20_giso_sma_err2
# p20_giso_insol
# p20_giso_insol_err1
# p20_giso_insol_err2
# p20_giso_teq
# p20_giso_teq_err1
# p20_giso_teq_err2
# p20_fur17_ao_obs
# p20_fur17_rcorr_avg
# p20_fur17_rcorr_avg_err
# p20_v18_Kepler
# p20_multi
# p20_v18_kepmag
# p20_v18_steff
# p20_v18_steff_err1
# p20_v18_steff_err2
# p20_v18_smet
# p20_v18_smet_err1
# p20_v18_smet_err2
# p20_v18_smass
# p20_v18_smass_err1
# p20_v18_smass_err2
# p20_v18_srad
# p20_v18_srad_err1
# p20_v18_srad_err2
# p20_v18_srho
# p20_v18_srho_err1
# p20_v18_srho_err2
# p20_v18_period
# p20_v18_period_err1
# p20_v18_period_err2
# p20_v18_ror
# p20_v18_ror_err1
# p20_v18_ror_err2
# p20_v18_rovera
# p20_v18_rovera_err1
# p20_v18_rovera_err2
# p20_v18_impact
# p20_v18_impact_err1
# p20_v18_impact_err2
# p20_v18_ld1
# p20_v18_ld2
# p20_v18_prad
# p20_v18_prad_err1
# p20_v18_prad_err2
# p20_v18_relrho
# p20_v18_relrho_err1
# p20_v18_relrho_err2
# p20_v18_ecc
# p20_v18_ecc_err1
# p20_v18_ecc_err2
# p20_dr25_BB1_cum
# p20_dr25_BB1_cum_err1
# p20_dr25_BB1_cum_err2
# p20_dr25_EP1_cum
# p20_dr25_EP1_cum_err1
# p20_dr25_EP1_cum_err2
# p20_dr25_PE1_cum
# p20_dr25_PE1_cum_err1
# p20_dr25_PE1_cum_err2
# p20_dr25_RD1_cum
# p20_dr25_RD1_cum_err1
# p20_dr25_RD1_cum_err2
# p20_dr25_RHO_cum
# p20_dr25_RHO_cum_err1
# p20_dr25_RHO_cum_err2
# p20_dr25_TAU1_cum
# p20_dr25_TAU1_cum_err1
# p20_dr25_TAU1_cum_err2
# p20_dr25_ZPT_cum
# p20_dr25_ZPT_cum_err1
# p20_dr25_ZPT_cum_err2
# p20_fgraz
# p20_tau0
# p20_tau
# p20_dr25_ror_v18_srad
# p20_dr25_ror_v18_srad_err1
# p20_dr25_ror_gdir_srad
# p20_dr25_ror_gdir_srad_err1
# p20_v18_ror_gdir_srad
# p20_v18_ror_gdir_srad_err1
# p20_Rtau
# b20_KIC
# b20_iso_mass
# b20_iso_mass_err1
# b20_iso_mass_err2
# b20_iso_teff
# b20_iso_teff_err1
# b20_iso_teff_err2
# b20_iso_logg
# b20_iso_logg_err1
# b20_iso_logg_err2
# b20_iso_feh
# b20_iso_feh_err1
# b20_iso_feh_err2
# b20_iso_rad
# b20_iso_rad_err1
# b20_iso_rad_err2
# b20_iso_rho
# b20_iso_rho_err1
# b20_iso_rho_err2
# b20_iso_lum
# b20_iso_lum_err1
# b20_iso_lum_err2
# b20_iso_age
# b20_unReAgeFlag
# b20_iso_age_err1
# b20_iso_age_err2
# b20_iso_dis
# b20_iso_dis_err1
# b20_iso_dis_err2
# b20_iso_avs
# b20_iso_gof
# b20_TAMS
# b20_log10_iso_age
# b20_E_log10_iso_age
# b20_e_log10_iso_age
# d20_kepid
# d20_source_id
# d20_ruwe
# d20_koi
# l20_KID
# l20_Rvar
# l20_v_t
# l20_v_b
# l20_ebv
# l20_Av
# l20_Av_errp
# l20_Av_errm
# l20_Av_std
# l20_bp_dered
# l20_rp_dered
# l20_bprp_dered
# l20_G_dered
# l20_teff_calc
# l20_abs_G
# l20_Prot_predict
# l20_Prot_log
# l20_Ro
# l20_vel_dis
# l20_kin_age
# Prot_KIC
# Prot_flag
# Prot_adopted
# Prot_ANG18
# Prot_MAZ15
# Prot_D20
# Prot_MCQ13
# Prot_WAL13
# Prot
# a18_Index
# a18_KOI
# a18_feh
# a18_feh_errm
# a18_feh_errp
# a18_logg
# a18_logg_errm
# a18_logg_errp
# a18_period
# a18_period_errm
# a18_period_errp
# a18_teff
# a18_teff_errm
# a18_teff_errp
# m15_KOI
# m15_KIC
# m15_Teff
# m15_log(g)
# m15_Prot
# m15_e_Prot
# m15_Rvar
# m15_LPH
# m15_w
# m15_D
# m15_N
# m15_C
# m15_G
# m15_T
# m15_F
# m15_R
# m15_M1
# m15_M2
# m13_KOI
# m13_KIC
# m13_Teff
# m13_log(g)
# m13_Rp
# m13_---
# m13_Porb
# m13_Prot
# m13_e_Prot
# m13_Rvar
# m13_Flag
# w13_KIC
# w13_KOI
# w13_Teff
# w13_logg
# w13_logVar
# w13_Per
# w13_e_Per
# w13_Ro
# w13_B-V
# w13_Age
# b18_Obs
# b18_Date
# b18_KOI
# b18_Kpmag
# b18_S/N
# b18_Teff
# b18_logg
# b18_[Fe/H]
# b18_Vt
# b18_EW(Li)
# b18_e_EW(Li)
# b18_A(Li)
# b18_e_A(Li)
# b18_tb2_KOI
# b18_tb2_S/N
# b18_tb2_Teff
# b18_tb2_logg
# b18_tb2_[Fe/H]
# b18_tb2_Vt
# b18_tb2_EW(Li)
# b18_tb2_e_EW(Li)
# b18_tb2_A(Li)
# b18_tb2_e_A(Li)
# b18_tb2_dA(Li)Hy
# s15_KOI
# s15_KIC
# s15_Teff
# s15_e_Teff
# s15_[Fe/H]
# s15_e_[Fe/H]
# s15_Mass
# s15_E_Mass
# s15_e_Mass
# s15_Radius
# s15_E_Radius
# s15_e_Radius
# s15_rho
# s15_E_rho
# s15_e_rho
# s15_logg
# s15_E_logg
# s15_e_logg
# s15_L
# s15_E_L
# s15_e_L
# s15_Age
# s15_E_Age
# s15_e_Age
# s15_Dist
# s15_E_Dist
# s15_e_Dist
# s15_Notes
# s15_n_Notes
# s15_Ref
# prot
# prot_err1
# prot_err2
# prot_numflag

# %% [markdown]
# ### Assigning rotation periods based on manual vetting results

# %%
cks['prot'] = np.nan*np.ones(len(cks))
cks['prot_err1'] = np.nan*np.ones(len(cks))
cks['prot_err2'] = np.nan*np.ones(len(cks))

for ref in ['a18', 'd20', 'm13', 'm15']:
    _mask = cks['Prot_adopted'] == ref
    
    if ref=='a18':
        cks['prot'][_mask] = cks['a18_period'][_mask]
        cks['prot_err1'][_mask] = cks['a18_period_errp'][_mask]
        cks['prot_err2'][_mask] = -1*cks['a18_period_errm'][_mask]
        
    elif ref=='d20':
        cks['prot'][_mask] = cks['Prot_D20'][_mask]
        cks['prot_err1'][_mask] = 0.1*cks['Prot_D20'][_mask]
        cks['prot_err2'][_mask] = -0.1*cks['Prot_D20'][_mask]
        
    elif ref=='m13':
        cks['prot'][_mask] = cks['m13_Prot'][_mask]
        cks['prot_err1'][_mask] = cks['m13_e_Prot'][_mask]
        cks['prot_err2'][_mask] = -1*cks['m13_e_Prot'][_mask]
        
    elif ref=='m15':
        cks['prot'][_mask] = cks['m15_Prot'][_mask]
        cks['prot_err1'][_mask] = cks['m15_e_Prot'][_mask]
        cks['prot_err2'][_mask] = -1*cks['m15_e_Prot'][_mask]
        
        
#Rotation period flags
cks['prot_numflag'] = np.zeros(len(cks), dtype=int)

for i in range(len(cks)):
    if str(cks['Prot_flag'][i])=='a':
        cks['prot_numflag'][i] = int(3)
    elif str(cks['Prot_flag'][i])=='b':
        cks['prot_numflag'][i] = int(2)
    elif str(cks['Prot_flag'][i])=='m':
        cks['prot_numflag'][i] = int(1)
    elif str(cks['Prot_flag'][i])=='nan':
        cks['prot_numflag'][i] = int(0)

# %%
#Response to referee
cks_copy = cks.copy()
cks_copy = cks_copy.drop_duplicates(subset='f18_KOI_star')

prot_flag = np.array(cks_copy['prot_numflag'])

for i in range(4):
    print('% of sample with rotation period flag of',i,'=',100.*len(prot_flag[prot_flag==i])/len(prot_flag))
# Out:
# % of sample with rotation period flag of 0 = 20.77375946173255
# % of sample with rotation period flag of 1 = 33.809924306139614
# % of sample with rotation period flag of 2 = 22.960470984020183
# % of sample with rotation period flag of 3 = 22.455845248107654

# %% [markdown]
# ### Rotation period table (Table 1)

# %%
prot_table = cks[['f18_KOI_int', 
                  'dr25_kepid', 
                  'prot', #'prot_err1', #'prot_err2', 
                  'Prot_adopted',
                  'prot_numflag',
                  'a18_period', #'a18_period_errm', #'a18_period_errp',
                  'm13_Prot',
                  'm15_Prot',
                  'w13_Per',
                  'Prot_D20']].copy()
    
#Renaming columns
prot_table = prot_table.rename(columns={"f18_KOI_int": "KOI", 
                                        "dr25_kepid": "KIC",
                                        "prot": "Prot",
                                        "Prot_adopted": "r_Prot",
                                        "prot_numflag": "f_Prot",
                                        "a18_period": "a18_Prot",
                                        "m13_Prot": "m13_Prot",
                                        "m15_Prot": "m15_Prot",
                                        "w13_Per": "w13_Prot",
                                        "Prot_D20": "d21_Prot"})    
    
#Only keep targets where at least one rotation period determination exists
#prot_table = prot_table[prot_table['prot'].notna()]

#Fill NaNs
#prot_table = prot_table.fillna(value={'dr25_kepid': -99})

#Remove duplicate rows
prot_table = prot_table.drop_duplicates(subset='KOI', keep='first')
#Formatting
#prot_table.dr25_kepid = prot_table.dr25_kepid.astype(int)    
prot_table.KIC = prot_table.KIC.astype('Int64')    

#Upper case references
prot_table = prot_table.replace("a18", "A18")
prot_table = prot_table.replace("m15", "M15")
prot_table = prot_table.replace("m13", "M13")
prot_table = prot_table.replace("w13", "W13")
prot_table = prot_table.replace("d20", "D21")

#Rounding
prot_table.Prot = prot_table.Prot.round(2)
prot_table.a18_Prot = prot_table.a18_Prot.round(2)
prot_table.m13_Prot = prot_table.m13_Prot.round(2)

tex_table = prot_table.to_latex(index=False)


prot_table.to_csv('./data/table1-submitted.csv', index=False)

#print(np.unique(prot_table['Prot_adopted']))
prot_table.head()
# Out:
#    KOI       KIC  Prot r_Prot  f_Prot  a18_Prot  m13_Prot  m15_Prot  w13_Prot  \
# 0    1  11446443   NaN    NaN       1     24.85       NaN     70.55       NaN
# 1    2  10666592   NaN    NaN       1     19.60       NaN     70.69       NaN
# 2    6   3248033   NaN    NaN       0     22.77       NaN       NaN       NaN
# 3    7  11853905   NaN    NaN       1     25.31       NaN       NaN       NaN
# 4    8   5903312   NaN    NaN       0     15.32       NaN       NaN     13.88
#
#    d21_Prot
# 0     43.37
# 1     46.65
# 2       NaN
# 3     41.53
# 4       NaN

# %%
print(tex_table)
# Out:
# \begin{tabular}{rrrlrrrrrr}
# \toprule
#  KOI &      KIC &  Prot & r\_Prot &  f\_Prot &  a18\_Prot &  m13\_Prot &  m15\_Prot &  w13\_Prot &  d21\_Prot \\
# \midrule
#    1 & 11446443 &   NaN &    NaN &       1 &     24.85 &       NaN &     70.55 &       NaN &     43.37 \\
#    2 & 10666592 &   NaN &    NaN &       1 &     19.60 &       NaN &     70.69 &       NaN &     46.65 \\
#    6 &  3248033 &   NaN &    NaN &       0 &     22.77 &       NaN &       NaN &       NaN &       NaN \\
#    7 & 11853905 &   NaN &    NaN &       1 &     25.31 &       NaN &       NaN &       NaN &     41.53 \\
#    8 &  5903312 &   NaN &    NaN &       0 &     15.32 &       NaN &       NaN &     13.88 &       NaN \\
#   10 &  6922244 &  7.46 &    A18 &       2 &      7.46 &       NaN &     82.12 &       NaN &      7.01 \\
#   17 & 10874614 &   NaN &    NaN &       1 &     18.29 &       NaN &     59.87 &       NaN &     18.34 \\
#   18 &  8191672 &   NaN &    NaN &       1 &     24.14 &       NaN &     81.97 &       NaN &     22.15 \\
#   20 & 11804465 &   NaN &    NaN &       1 &     29.59 &       NaN &     59.50 &       NaN &     21.22 \\
#   22 &  9631995 &   NaN &    NaN &       1 &     44.48 &       NaN &    126.37 &       NaN &     39.19 \\
#   41 &  6521045 &   NaN &    NaN &       1 &     25.78 &     24.99 &     24.99 &       NaN &     30.57 \\
#   46 & 10905239 &   NaN &    NaN &       1 &     21.78 &       NaN &       NaN &       NaN &     29.99 \\
#   49 &  9527334 &  8.74 &    A18 &       3 &      8.74 &      8.55 &      8.59 &      8.60 &      8.56 \\
#   63 & 11554435 &  5.49 &    A18 &       3 &      5.49 &      5.41 &       NaN &      5.39 &      5.40 \\
#   64 &  7051180 &  2.23 &    A18 &       3 &      2.23 &       NaN &       NaN &      2.22 &      2.22 \\
#   69 &  3544595 &   NaN &    NaN &       1 &     29.63 &       NaN &     57.32 &       NaN &     14.40 \\
#   70 &  6850504 & 27.92 &    A18 &       2 &     27.92 &       NaN &     27.72 &     28.25 &     13.75 \\
#   72 & 11904151 &   NaN &    NaN &       1 &     48.56 &       NaN &     18.20 &       NaN &     12.81 \\
#   75 &  7199397 &   NaN &    NaN &       1 &     25.28 &       NaN &     26.41 &     21.71 &      9.63 \\
#   82 & 10187017 & 26.55 &    A18 &       3 &     26.55 &     26.57 &     26.40 &     26.74 &     27.02 \\
#   84 &  2571238 & 20.23 &    A18 &       2 &     20.23 &       NaN &     20.27 &     32.54 &     15.27 \\
#   85 &  5866724 &  7.90 &    A18 &       3 &      7.90 &      7.91 &      7.88 &       NaN &      8.29 \\
#   92 &  7941200 & 16.38 &    A18 &       3 &     16.38 &     16.20 &     16.18 &       NaN &     15.68 \\
#   94 &  6462863 & 21.86 &    A18 &       2 &     21.86 &       NaN &       NaN &       NaN &     22.33 \\
#   97 &  5780885 &   NaN &    NaN &       1 &     15.89 &       NaN &    103.25 &       NaN &     16.69 \\
#  102 &  8456679 &   NaN &    NaN &       1 &     18.77 &       NaN &     43.70 &       NaN &     21.20 \\
#  103 &  2444412 & 22.97 &    A18 &       3 &     22.97 &     23.16 &     23.28 &     10.71 &     11.54 \\
#  104 & 10318874 & 44.31 &    M15 &       2 &       NaN &       NaN &     44.31 &       NaN &     44.39 \\
#  105 &  8711794 &   NaN &    NaN &       1 &     19.72 &       NaN &     43.09 &       NaN &     20.36 \\
#  107 & 11250587 & 17.42 &    A18 &       3 &     17.42 &     17.33 &     17.58 &       NaN &     17.12 \\
#  108 &  4914423 &   NaN &    NaN &       1 &     21.66 &       NaN &     20.92 &       NaN &     11.54 \\
#  110 &  9450647 &   NaN &    NaN &       1 &     21.63 &       NaN &     11.04 &       NaN &      8.26 \\
#  111 &  6678383 &   NaN &    NaN &       1 &     18.03 &       NaN &       NaN &       NaN &     15.86 \\
#  112 & 10984090 & 15.73 &    A18 &       2 &     15.73 &       NaN &     32.08 &       NaN &     14.89 \\
#  115 &  9579641 & 16.34 &    A18 &       2 &     16.34 &     16.85 &     16.78 &       NaN &     17.36 \\
#  116 &  8395660 & 22.51 &    A18 &       2 &     22.51 &       NaN &     20.33 &       NaN &     11.43 \\
#  117 & 10875245 & 22.35 &    A18 &       2 &     22.35 &       NaN &     21.56 &       NaN &     20.28 \\
#  118 &  3531558 & 20.60 &    A18 &       2 &     20.60 &       NaN &     49.68 &       NaN &     21.03 \\
#  122 &  8349582 & 15.73 &    M15 &       2 &     34.16 &       NaN &     15.73 &       NaN &     17.22 \\
#  123 &  5094751 &   NaN &    NaN &       1 &     26.42 &       NaN &     43.72 &       NaN &     13.53 \\
#  124 & 11086270 &   NaN &    NaN &       1 &     36.56 &       NaN &     54.78 &       NaN &     30.95 \\
#  127 &  8359498 & 30.49 &    A18 &       2 &     30.49 &       NaN &     33.24 &       NaN &     15.01 \\
#  128 & 11359879 &   NaN &    NaN &       1 &     23.48 &       NaN &     35.55 &       NaN &     12.13 \\
#  134 &  9032900 &   NaN &    NaN &       0 &      7.68 &       NaN &       NaN &      7.42 &       NaN \\
#  135 &  9818381 & 12.86 &    A18 &       3 &     12.86 &     12.85 &       NaN &     12.38 &      6.41 \\
#  137 &  8644288 & 16.40 &    A18 &       2 &     16.40 &       NaN &     44.74 &       NaN &     17.58 \\
#  139 &  8559644 & 17.14 &    A18 &       2 &     17.14 &     16.96 &     16.91 &       NaN &     16.20 \\
#  142 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  144 &  4180280 & 39.72 &    A18 &       2 &     39.72 &       NaN &     44.85 &       NaN &     16.93 \\
#  145 &  9904059 &   NaN &    NaN &       1 &       NaN &       NaN &       NaN &       NaN &     13.14 \\
#  148 &  5735762 & 38.35 &    A18 &       2 &     38.35 &       NaN &     36.57 &     39.36 &     19.40 \\
#  149 &  3835670 &   NaN &    NaN &       1 &     20.29 &       NaN &     56.09 &       NaN &     13.84 \\
#  150 &  7626506 &   NaN &    NaN &       1 &     15.62 &       NaN &     25.74 &       NaN &     18.72 \\
#  152 &  8394721 &  4.71 &    A18 &       2 &      4.71 &       NaN &     64.01 &       NaN &      4.92 \\
#  153 & 12252424 & 26.86 &    A18 &       2 &     26.86 &       NaN &     45.46 &       NaN &     27.55 \\
#  155 &  8030148 &   NaN &    NaN &       1 &     30.16 &       NaN &    112.96 &       NaN &     14.25 \\
#  157 &  6541920 &   NaN &    NaN &       1 &     21.07 &       NaN &     25.25 &       NaN &     32.03 \\
#  159 &  8972058 & 13.83 &    A18 &       2 &     13.83 &       NaN &     80.20 &       NaN &     12.92 \\
#  161 &  5084942 & 19.52 &    A18 &       2 &     19.52 &       NaN &     42.39 &     26.74 &     23.44 \\
#  166 &  2441495 & 16.51 &    A18 &       2 &     16.51 &       NaN &     71.94 &       NaN &     16.73 \\
#  167 & 11666881 &   NaN &    NaN &       1 &       NaN &       NaN &     26.48 &       NaN &     13.01 \\
#  168 & 11512246 &   NaN &    NaN &       1 &      9.11 &       NaN &     50.13 &       NaN &     14.91 \\
#  171 &  7831264 &  8.83 &    A18 &       3 &      8.83 &       NaN &      8.42 &      8.60 &      8.32 \\
#  172 &  8692861 &   NaN &    NaN &       1 &     46.43 &       NaN &     81.91 &       NaN &     19.59 \\
#  173 & 11402995 &   NaN &    NaN &       1 &       NaN &       NaN &     55.39 &       NaN &     42.03 \\
#  174 & 10810838 & 23.40 &    A18 &       2 &     23.40 &       NaN &     78.08 &       NaN &     16.65 \\
#  176 &  6442377 &  5.83 &    A18 &       2 &      5.83 &       NaN &     58.37 &       NaN &      5.83 \\
#  179 &  9663113 &   NaN &    NaN &       1 &     15.02 &       NaN &     12.78 &       NaN &     12.28 \\
#  180 &  9573539 & 15.78 &    A18 &       3 &     15.78 &     15.76 &     15.59 &     15.94 &      7.87 \\
#  186 & 12019440 & 21.20 &    A18 &       2 &     21.20 &       NaN &     21.43 &       NaN &     21.73 \\
#  191 &  5972334 &   NaN &    NaN &       1 &     28.78 &       NaN &     55.10 &       NaN &     20.45 \\
#  193 & 10799735 &   NaN &    NaN &       0 &       NaN &       NaN &     23.23 &       NaN &       NaN \\
#  195 & 11502867 &   NaN &    NaN &       1 &     21.98 &       NaN &    142.09 &       NaN &     16.66 \\
#  197 &  2987027 & 21.57 &    A18 &       2 &     21.57 &     35.21 &     34.47 &       NaN &     16.45 \\
#  201 &  6849046 &   NaN &    NaN &       1 &     15.97 &       NaN &       NaN &       NaN &     23.97 \\
#  203 & 10619192 & 12.27 &    A18 &       3 &     12.27 &     12.16 &     12.05 &     12.50 &     12.26 \\
#  209 & 10723750 & 10.93 &    A18 &       2 &     10.93 &       NaN &     10.72 &       NaN &     10.68 \\
#  211 & 10656508 &   NaN &    NaN &       1 &     19.56 &       NaN &       NaN &       NaN &      7.65 \\
#  214 & 11046458 & 15.10 &    A18 &       2 &     15.10 &       NaN &     31.40 &       NaN &     14.68 \\
#  232 &  4833421 &   NaN &    NaN &       0 &     22.16 &       NaN &     61.76 &       NaN &     12.69 \\
#  237 &  8041216 & 12.13 &    D21 &       2 &     23.84 &     23.30 &     23.25 &     27.73 &     12.13 \\
#  238 &  7219825 &   NaN &    NaN &       0 &     10.39 &       NaN &     20.24 &       NaN &     35.60 \\
#  241 & 11288051 &   NaN &    NaN &       0 &      1.10 &       NaN &     49.42 &       NaN &     32.68 \\
#  244 &  4349452 &   NaN &    M15 &       2 &       NaN &     23.15 &       NaN &     24.55 &     23.20 \\
#  245 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  246 & 11295426 &   NaN &    NaN &       1 &     16.38 &       NaN &       NaN &       NaN &     17.23 \\
#  257 &  5514383 &  7.94 &    A18 &       2 &      7.94 &      7.86 &      7.86 &       NaN &     40.10 \\
#  260 &  8292840 &  7.33 &    A18 &       2 &      7.33 &       NaN &       NaN &       NaN &      7.21 \\
#  261 &  5383248 & 15.17 &    A18 &       3 &     15.17 &     14.92 &     14.86 &     15.30 &     15.25 \\
#  262 & 11807274 &  7.86 &    A18 &       3 &      7.86 &      7.55 &      7.60 &       NaN &      7.97 \\
#  263 & 10514430 &   NaN &    NaN &       0 &       NaN &       NaN &     39.29 &       NaN &       NaN \\
#  265 & 12024120 & 12.48 &    A18 &       2 &     12.48 &       NaN &     24.49 &       NaN &     12.28 \\
#  266 &  7375348 &   NaN &    NaN &       1 &       NaN &       NaN &       NaN &       NaN &      3.35 \\
#  268 &  3425851 &  7.87 &    M13 &       3 &       NaN &      7.87 &       NaN &      7.97 &      7.87 \\
#  269 &  7670943 &  6.11 &    A18 &       2 &      6.11 &      5.27 &      5.21 &       NaN &      5.24 \\
#  271 &  9451706 & 10.20 &    A18 &       2 &     10.20 &     10.12 &     10.10 &       NaN &      9.54 \\
#  273 &  3102384 &   NaN &    NaN &       1 &     27.37 &       NaN &     37.33 &       NaN &     14.09 \\
#  274 &  8077137 & 13.07 &    M15 &       2 &     20.70 &       NaN &     13.07 &       NaN &     13.62 \\
#  275 & 10586004 &   NaN &    NaN &       1 &     29.87 &       NaN &     29.78 &       NaN &     10.02 \\
#  276 & 11133306 &   NaN &    NaN &       0 &     19.22 &       NaN &     55.45 &       NaN &     16.62 \\
#  277 & 11401755 &   NaN &    NaN &       1 &     20.24 &       NaN &     17.62 &       NaN &     17.56 \\
#  279 & 12314973 & 10.24 &    A18 &       2 &     10.24 &     20.80 &     20.82 &       NaN &     10.43 \\
#  280 &  4141376 &   NaN &    NaN &       0 &     22.50 &       NaN &     27.83 &       NaN &     37.19 \\
#  281 &  4143755 & 22.29 &    A18 &       2 &     22.29 &       NaN &     65.65 &       NaN &     23.67 \\
#  282 &  5088536 &   NaN &    NaN &       1 &     27.47 &       NaN &     35.82 &     34.80 &     11.88 \\
#  283 &  5695396 & 17.88 &    A18 &       3 &     17.88 &     17.52 &     17.43 &     17.21 &     19.09 \\
#  284 &  6021275 &   NaN &    NaN &       0 &     10.55 &       NaN &     40.94 &       NaN &     20.65 \\
#  285 &  6196457 & 17.00 &    A18 &       2 &     17.00 &       NaN &     32.50 &       NaN &     16.32 \\
#  288 &  9592705 & 13.57 &    A18 &       3 &     13.57 &     13.38 &     13.34 &       NaN &     13.55 \\
#  289 & 10386922 &   NaN &    NaN &       1 &     29.26 &       NaN &     32.44 &       NaN &     15.27 \\
#  291 & 10933561 &   NaN &    NaN &       1 &     20.93 &       NaN &     27.99 &       NaN &     15.49 \\
#  292 & 11075737 & 21.81 &    A18 &       2 &     21.81 &       NaN &     19.77 &       NaN &     11.65 \\
#  294 & 11259686 & 13.94 &    A18 &       2 &     13.94 &     12.10 &     12.09 &     12.37 &     10.87 \\
#  295 & 11547513 & 15.75 &    M15 &       2 &     28.86 &     15.72 &     15.75 &       NaN &     14.65 \\
#  296 & 11802615 &   NaN &    NaN &       1 &     20.94 &       NaN &     78.75 &       NaN &     14.95 \\
#  297 & 11905011 &  8.81 &    A18 &       2 &      8.81 &      8.29 &      8.28 &      8.27 &      8.60 \\
#  299 &  2692377 & 23.42 &    A18 &       2 &     23.42 &     22.96 &     23.00 &     23.43 &     11.45 \\
#  301 &  3642289 &   NaN &    NaN &       0 &     14.15 &       NaN &     82.00 &       NaN &     16.14 \\
#  303 &  5966322 & 21.53 &    D21 &       2 &     18.71 &       NaN &     56.21 &       NaN &     21.53 \\
#  304 &  6029239 & 16.78 &    A18 &       2 &     16.78 &     16.50 &     16.57 &     14.42 &      8.55 \\
#  305 &  6063220 & 31.46 &    A18 &       2 &     31.46 &     29.55 &     29.78 &     14.99 &     15.29 \\
#  306 &  6071903 & 17.60 &    A18 &       3 &     17.60 &     17.82 &     17.77 &     17.84 &     18.27 \\
#  307 &  6289257 & 14.31 &    A18 &       2 &     14.31 &       NaN &     13.62 &       NaN &     14.61 \\
#  308 &  6291837 &  6.02 &    M15 &       2 &     23.34 &       NaN &      6.02 &       NaN &     14.33 \\
#  313 &  7419318 &   NaN &    NaN &       0 &     20.51 &       NaN &     39.15 &       NaN &     14.99 \\
#  315 &  7700622 & 33.40 &    A18 &       2 &     33.40 &     31.43 &     31.63 &       NaN &     30.60 \\
#  316 &  8008067 & 19.68 &    A18 &       2 &     19.68 &       NaN &     26.40 &       NaN &     15.13 \\
#  317 &  8121310 &   NaN &    NaN &       0 &      9.69 &       NaN &     70.93 &       NaN &     40.98 \\
#  318 &  8156120 &  5.24 &    A18 &       3 &      5.24 &      4.92 &      4.99 &       NaN &      4.95 \\
#  321 &  8753657 &   NaN &    NaN &       0 &     18.37 &       NaN &     76.54 &       NaN &     16.77 \\
#  323 &  9139084 &  7.60 &    A18 &       3 &      7.60 &      7.64 &      7.64 &      7.97 &      7.64 \\
#  327 &  9881662 & 13.30 &    A18 &       2 &     13.30 &     24.52 &     24.91 &       NaN &     12.03 \\
#  328 &  9895004 &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &     15.62 &       NaN \\
#  330 & 11361646 & 11.84 &    D21 &       2 &     29.55 &       NaN &     25.60 &     27.73 &     11.84 \\
#  331 & 10285631 & 16.87 &    M15 &       2 &       NaN &       NaN &     16.87 &       NaN &     17.93 \\
#  332 & 10290666 &   NaN &    NaN &       0 &     18.42 &       NaN &     52.23 &       NaN &     24.43 \\
#  333 & 10337258 &  7.26 &    A18 &       3 &      7.26 &      6.89 &      6.87 &       NaN &      7.28 \\
#  337 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  338 & 10552611 & 30.77 &    M13 &       2 &     18.78 &     30.77 &     61.17 &       NaN &     33.02 \\
#  340 & 10616571 &   NaN &    NaN &       0 &     12.82 &     12.94 &       NaN &     12.93 &       NaN \\
#  341 & 10878263 & 18.44 &    A18 &       3 &     18.44 &     18.55 &     18.31 &     19.21 &     18.46 \\
#  343 & 10982872 &  9.72 &    D21 &       2 &     29.48 &       NaN &     29.54 &       NaN &      9.72 \\
#  344 & 11015108 & 12.18 &    D21 &       2 &     23.79 &     24.15 &     24.16 &       NaN &     12.18 \\
#  345 & 11074541 & 34.93 &    A18 &       2 &     34.93 &     35.05 &     34.44 &     34.80 &     35.05 \\
#  346 & 11100383 & 15.15 &    M13 &       3 &     15.54 &     15.15 &     15.08 &     14.99 &     15.16 \\
#  348 & 11194032 & 35.94 &    A18 &       2 &     35.94 &     37.09 &     36.89 &     41.54 &     37.74 \\
#  350 & 11395587 & 20.78 &    A18 &       2 &     20.78 &     19.67 &     19.71 &       NaN &     17.85 \\
#  351 & 11442793 &   NaN &    NaN &       0 &     17.94 &       NaN &     13.64 &       NaN &      9.76 \\
#  352 & 11521793 & 13.17 &    A18 &       2 &     13.17 &       NaN &     41.38 &       NaN &     13.71 \\
#  355 & 11621223 & 10.80 &    A18 &       2 &     10.80 &     10.39 &     10.41 &       NaN &     11.00 \\
#  356 & 11624249 & 21.40 &    A18 &       2 &     21.40 &       NaN &     58.31 &       NaN &     17.52 \\
#  360 & 12107021 &   NaN &    NaN &       0 &     29.12 &       NaN &       NaN &       NaN &       NaN \\
#  361 & 12404954 & 23.77 &    A18 &       2 &     23.77 &     24.50 &     24.33 &       NaN &     21.51 \\
#  364 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  365 & 11623629 & 16.06 &    A18 &       2 &     16.06 &       NaN &     33.00 &       NaN &     47.11 \\
#  367 &  4815520 & 11.82 &    D21 &       2 &     16.28 &     23.37 &     23.49 &       NaN &     11.82 \\
#  369 &  7175184 &  8.21 &    A18 &       3 &      8.21 &       NaN &      8.12 &       NaN &      8.09 \\
#  370 &  8494142 &   NaN &    NaN &       1 &     23.23 &       NaN &     74.93 &       NaN &     13.53 \\
#  371 &  5652983 &   NaN &    NaN &       0 &     20.04 &       NaN &       NaN &       NaN &       NaN \\
#  372 &  6471021 & 11.97 &    A18 &       3 &     11.97 &     11.77 &     11.80 &     11.90 &     11.97 \\
#  373 &  7364176 &   NaN &    NaN &       1 &     21.74 &       NaN &     32.98 &       NaN &     11.06 \\
#  374 &  8686097 &   NaN &    NaN &       0 &     51.40 &       NaN &     27.66 &       NaN &     30.51 \\
#  375 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  377 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  379 &  2446113 &   NaN &    NaN &       1 &     25.79 &       NaN &     34.14 &       NaN &     15.62 \\
#  384 &  3353050 & 23.24 &    A18 &       2 &     23.24 &       NaN &     45.83 &       NaN &     21.10 \\
#  385 &  3446746 & 14.81 &    D21 &       2 &     19.35 &       NaN &     29.56 &       NaN &     14.81 \\
#  386 &  3656121 & 14.39 &    A18 &       2 &     14.39 &     13.81 &     13.85 &       NaN &     13.63 \\
#  387 &  3733628 & 20.30 &    M15 &       3 &     20.65 &     20.31 &     20.30 &     20.25 &     20.21 \\
#  388 &  3831053 &   NaN &    NaN &       0 &     38.48 &       NaN &     61.23 &       NaN &     45.07 \\
#  392 &  3942670 &   NaN &    NaN &       0 &     25.54 &       NaN &     78.66 &       NaN &     14.51 \\
#  393 &  3964109 &   NaN &    NaN &       0 &     24.18 &       NaN &      0.14 &       NaN &     42.54 \\
#  399 &  7289157 &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &      7.97 &       NaN \\
#  401 &  3217264 &   NaN &    NaN &       1 &     18.83 &       NaN &     36.53 &       NaN &     18.12 \\
#  403 &  4247092 &   NaN &    NaN &       0 &     20.89 &       NaN &       NaN &       NaN &       NaN \\
#  408 &  5351250 & 17.87 &    A18 &       3 &     17.87 &     17.56 &     17.48 &     18.28 &     17.54 \\
#  409 &  5444548 & 13.81 &    A18 &       2 &     13.81 &       NaN &     20.62 &       NaN &     12.31 \\
#  415 &  6289650 &   NaN &    NaN &       0 &     29.07 &       NaN &     61.73 &       NaN &     19.57 \\
#  416 &  6508221 &   NaN &    NaN &       0 &     16.72 &       NaN &     41.92 &       NaN &     19.10 \\
#  427 & 10189546 & 26.32 &    A18 &       2 &     26.32 &     26.28 &     25.84 &     13.39 &     13.42 \\
#  431 & 10843590 & 30.28 &    A18 &       2 &     30.28 &       NaN &     28.68 &       NaN &     14.52 \\
#  433 & 10937029 &   NaN &    NaN &       0 &     23.51 &       NaN &     29.23 &       NaN &     16.03 \\
#  435 & 11709124 &   NaN &    NaN &       1 &     35.92 &       NaN &     60.06 &       NaN &     15.75 \\
#  439 & 12470954 & 19.89 &    D21 &       2 &     36.73 &       NaN &       NaN &       NaN &     19.89 \\
#  440 &  2438264 & 34.96 &    A18 &       2 &     34.96 &       NaN &     37.10 &     34.80 &     34.04 \\
#  442 &  3745690 &   NaN &    NaN &       0 &     20.96 &       NaN &     75.74 &       NaN &     44.09 \\
#  444 &  3847138 & 16.08 &    A18 &       2 &     16.08 &     26.40 &     26.78 &       NaN &     14.43 \\
#  446 &  4633570 & 15.57 &    D21 &       2 &       NaN &     31.30 &     31.33 &       NaN &     15.57 \\
#  448 &  5640085 & 10.50 &    M15 &       3 &       NaN &     10.47 &     10.50 &     10.27 &     10.47 \\
#  456 &  7269974 &   NaN &    NaN &       0 &     23.32 &       NaN &     77.01 &       NaN &     23.20 \\
#  457 &  7440748 & 28.56 &    A18 &       3 &     28.56 &     27.88 &     27.86 &     26.74 &     27.22 \\
#  459 &  7977197 &   NaN &    NaN &       0 &       NaN &       NaN &     32.18 &       NaN &     19.31 \\
#  464 &  8890783 & 26.22 &    M15 &       2 &       NaN &     26.34 &     26.22 &       NaN &     13.19 \\
#  465 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  466 &  9008220 &   NaN &    NaN &       0 &     14.87 &     14.85 &     14.64 &     14.70 &       NaN \\
#  474 & 10460984 & 15.33 &    M15 &       2 &       NaN &     15.35 &     15.33 &       NaN &      7.57 \\
#  475 & 10577994 &   NaN &    NaN &       1 &     17.47 &       NaN &     36.32 &       NaN &     21.14 \\
#  479 & 11015323 &   NaN &    NaN &       1 &     27.18 &       NaN &     56.94 &       NaN &     29.13 \\
#  481 & 11192998 & 23.81 &    M15 &       2 &       NaN &       NaN &     23.81 &       NaN &     11.66 \\
#  486 & 12404305 &   NaN &    NaN &       0 &       NaN &       NaN &     73.37 &       NaN &     20.57 \\
#  490 &  3239945 &   NaN &    NaN &       0 &       NaN &       NaN &     77.58 &     40.42 &     13.37 \\
#  500 &  4852528 & 25.56 &    M15 &       3 &       NaN &     25.57 &     25.56 &       NaN &     12.90 \\
#  505 &  5689351 & 25.59 &    A18 &       3 &     25.59 &     25.43 &     25.36 &       NaN &     12.71 \\
#  508 &  6266741 &   NaN &    NaN &       1 &     18.07 &       NaN &     75.80 &       NaN &     16.63 \\
#  509 &  6381846 & 22.00 &    A18 &       3 &     22.00 &     21.51 &     21.46 &     23.05 &     10.75 \\
#  510 &  6422155 & 23.34 &    A18 &       3 &     23.34 &     23.29 &     23.31 &       NaN &     24.23 \\
#  511 &  6451936 & 15.02 &    M15 &       3 &       NaN &     15.00 &     15.02 &       NaN &     14.39 \\
#  517 &  8015907 & 18.69 &    A18 &       3 &     18.69 &     19.32 &     18.83 &     18.73 &     19.22 \\
#  518 &  8017703 &   NaN &    NaN &       1 &     24.95 &       NaN &     43.72 &       NaN &     11.52 \\
#  519 &  8022244 &   NaN &    NaN &       1 &       NaN &       NaN &     20.57 &       NaN &     13.11 \\
#  520 &  8037145 & 33.89 &    M15 &       2 &       NaN &     34.16 &     33.89 &       NaN &     17.16 \\
#  523 &  8806123 &   NaN &    NaN &       1 &       NaN &       NaN &      4.49 &       NaN &     23.27 \\
#  528 &  9941859 &   NaN &    NaN &       0 &       NaN &       NaN &     65.71 &       NaN &     37.29 \\
#  534 & 10554999 & 16.53 &    A18 &       2 &     16.53 &       NaN &     36.86 &       NaN &     17.37 \\
#  543 & 11823054 &   NaN &    NaN &       1 &     34.77 &       NaN &     45.14 &     38.35 &     15.53 \\
#  546 & 12058931 &   NaN &    NaN &       1 &       NaN &       NaN &     44.29 &       NaN &     11.37 \\
#  548 & 12600735 &   NaN &    NaN &       1 &     17.50 &       NaN &     68.58 &       NaN &     16.89 \\
#  550 &  4165473 & 22.49 &    A18 &       3 &     22.49 &     22.59 &     22.58 &       NaN &     22.31 \\
#  551 &  4270253 &   NaN &    NaN &       0 &       NaN &       NaN &     76.25 &       NaN &     21.69 \\
#  555 &  5709725 & 15.85 &    A18 &       2 &     15.85 &       NaN &     34.10 &       NaN &     12.52 \\
#  561 &  6665695 &   NaN &    NaN &       1 &     16.35 &       NaN &     41.41 &       NaN &     13.69 \\
#  564 &  6786037 &   NaN &    NaN &       0 &     28.20 &       NaN &     21.10 &       NaN &     11.63 \\
#  567 &  7445445 &   NaN &    NaN &       1 &       NaN &       NaN &     81.84 &       NaN &     13.37 \\
#  568 &  7595157 & 30.92 &    A18 &       2 &     30.92 &       NaN &     28.05 &       NaN &     12.24 \\
#  569 &  8008206 & 31.69 &    A18 &       2 &     31.69 &     31.78 &     31.52 &     35.62 &     15.98 \\
#  572 &  8193178 &   NaN &    NaN &       1 &     19.24 &       NaN &     42.11 &       NaN &     16.94 \\
#  573 &  8344004 &   NaN &    NaN &       0 &     33.09 &       NaN &     77.82 &       NaN &     26.79 \\
#  574 &  8355239 &   NaN &    NaN &       1 &     35.71 &       NaN &     41.60 &     34.01 &     13.93 \\
#  577 &  8558011 &   NaN &    NaN &       1 &     22.28 &       NaN &     37.74 &       NaN &     18.51 \\
#  579 &  8616637 & 31.11 &    A18 &       3 &     31.11 &     29.98 &     29.90 &     15.30 &     28.58 \\
#  582 &  9020160 & 21.17 &    M15 &       3 &       NaN &     21.25 &     21.17 &     22.03 &     21.29 \\
#  584 &  9146018 & 21.28 &    A18 &       2 &     21.28 &       NaN &     31.67 &       NaN &     10.82 \\
#  590 &  9782691 & 13.63 &    A18 &       3 &     13.63 &     13.30 &     13.33 &     14.70 &     13.46 \\
#  597 & 10600261 &   NaN &    NaN &       0 &       NaN &       NaN &     19.63 &       NaN &     17.35 \\
#  598 & 10656823 & 26.42 &    A18 &       3 &     26.42 &     25.83 &     25.81 &     25.82 &     25.84 \\
#  600 & 10718726 &   NaN &    NaN &       1 &     32.08 &       NaN &     31.79 &     36.49 &     15.70 \\
#  601 & 10973664 & 10.86 &    M15 &       3 &       NaN &     11.00 &     10.86 &      5.39 &     10.91 \\
#  611 &  6309763 & 10.40 &    A18 &       2 &     10.40 &       NaN &      5.00 &       NaN &      5.06 \\
#  612 &  6587002 &   NaN &    NaN &       1 &     29.89 &       NaN &     33.71 &       NaN &     14.39 \\
#  620 & 11773022 &  8.25 &    A18 &       3 &      8.25 &      8.22 &      8.17 &      8.27 &      8.18 \\
#  623 & 12068975 & 21.70 &    A18 &       2 &     21.70 &       NaN &     21.80 &       NaN &     15.05 \\
#  624 &  3541946 & 15.38 &    M15 &       3 &       NaN &     15.37 &     15.38 &      7.97 &      7.68 \\
#  626 &  4478168 &   NaN &    NaN &       0 &     37.59 &       NaN &     51.61 &       NaN &     13.58 \\
#  627 &  4563268 & 13.06 &    A18 &       2 &     13.06 &       NaN &     12.46 &       NaN &     12.34 \\
#  628 &  4644604 &   NaN &    NaN &       1 &     17.38 &       NaN &     25.99 &       NaN &     13.29 \\
#  629 &  4656049 &   NaN &    NaN &       1 &     10.44 &       NaN &     69.86 &       NaN &     22.07 \\
#  632 &  4827723 & 21.77 &    A18 &       3 &     21.77 &     22.41 &     22.35 &     17.43 &     22.72 \\
#  633 &  4841374 &   NaN &    NaN &       0 &       NaN &       NaN &     39.30 &       NaN &     16.61 \\
#  635 &  5020319 &  8.90 &    A18 &       3 &      8.90 &      8.88 &      8.92 &       NaN &      8.79 \\
#  638 &  5113822 & 18.14 &    A18 &       3 &     18.14 &     17.79 &     17.99 &       NaN &     17.59 \\
#  639 &  5120087 &  8.65 &    A18 &       2 &      8.65 &      7.77 &      7.79 &       NaN &      6.90 \\
#  644 &  5356593 &   NaN &    NaN &       0 &      8.91 &       NaN &       NaN &      8.68 &       NaN \\
#  645 &  5374854 &   NaN &    NaN &       1 &     20.84 &       NaN &     65.57 &       NaN &     16.57 \\
#  647 &  5531694 &   NaN &    NaN &       0 &       NaN &       NaN &     49.63 &       NaN &     12.72 \\
#  649 &  5613330 &   NaN &    NaN &       1 &     23.48 &       NaN &     10.33 &       NaN &     11.24 \\
#  650 &  5786676 &   NaN &    NaN &       1 &     14.30 &     36.37 &     69.34 &     37.40 &     32.79 \\
#  654 &  5941160 & 19.12 &    A18 &       3 &     19.12 &     18.94 &     18.92 &       NaN &     19.55 \\
#  655 &  5966154 &   NaN &    NaN &       1 &     10.40 &       NaN &     17.26 &       NaN &      8.87 \\
#  657 &  6020753 & 16.16 &    A18 &       2 &     16.16 &       NaN &     41.01 &       NaN &     13.95 \\
#  658 &  6062088 & 15.23 &    A18 &       3 &     15.23 &     15.24 &     15.26 &     21.71 &     16.27 \\
#  659 &  6125481 &  7.54 &    A18 &       2 &      7.54 &       NaN &      6.68 &       NaN &      6.71 \\
#  660 &  6267535 &   NaN &    NaN &       0 &     29.85 &       NaN &     32.10 &       NaN &     14.95 \\
#  661 &  6347299 & 16.82 &    A18 &       2 &     16.82 &     16.93 &     16.90 &       NaN &      8.72 \\
#  662 &  6365156 &   NaN &    NaN &       0 &     22.01 &       NaN &     49.98 &       NaN &     29.96 \\
#  664 &  6442340 &   NaN &    NaN &       0 &     31.15 &       NaN &     72.52 &       NaN &     17.77 \\
#  665 &  6685609 & 15.93 &    A18 &       2 &     15.93 &     15.42 &     15.48 &      7.69 &     14.56 \\
#  666 &  6707835 & 28.32 &    A18 &       2 &     28.32 &       NaN &     27.91 &     42.72 &     18.63 \\
#  670 &  7033671 &   NaN &    NaN &       0 &       NaN &       NaN &    144.24 &       NaN &     32.97 \\
#  671 &  7040629 &   NaN &    NaN &       1 &     11.24 &       NaN &     60.46 &       NaN &     12.08 \\
#  672 &  7115785 & 27.26 &    A18 &       2 &     27.26 &       NaN &     27.48 &     30.55 &     16.72 \\
#  673 &  7124613 &  4.89 &    A18 &       3 &      4.89 &      4.79 &      4.79 &      4.59 &      4.99 \\
#  674 &  7277317 &   NaN &    NaN &       0 &     15.62 &       NaN &       NaN &       NaN &     13.22 \\
#  678 &  7509886 & 13.79 &    A18 &       3 &     13.79 &     13.84 &     13.74 &     13.88 &     13.88 \\
#  679 &  7515212 & 21.60 &    A18 &       2 &     21.60 &       NaN &     21.43 &     18.28 &      9.63 \\
#  680 &  7529266 &   NaN &    NaN &       1 &     33.20 &       NaN &     72.80 &       NaN &     20.27 \\
#  682 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  683 &  7630229 & 16.62 &    A18 &       3 &     16.62 &     16.49 &     16.47 &     16.55 &      8.54 \\
#  684 &  7730747 &   NaN &    NaN &       0 &     21.93 &       NaN &     85.67 &       NaN &     30.95 \\
#  685 &  7764367 &   NaN &    NaN &       0 &     16.61 &       NaN &     45.35 &       NaN &      4.98 \\
#  686 &  7906882 & 18.79 &    A18 &       2 &     18.79 &       NaN &     16.91 &       NaN &     20.06 \\
#  687 &  7976520 & 18.34 &    A18 &       2 &     18.34 &     19.02 &       NaN &     18.73 &     18.16 \\
#  688 &  8161561 &   NaN &    NaN &       1 &     25.27 &       NaN &     26.10 &       NaN &     23.04 \\
#  689 &  8361905 &   NaN &    NaN &       0 &     20.22 &       NaN &     10.47 &       NaN &     24.19 \\
#  691 &  8480285 &   NaN &    NaN &       1 &     30.84 &       NaN &     32.03 &       NaN &     19.93 \\
#  692 &  8557374 &   NaN &    NaN &       1 &     27.55 &       NaN &     26.78 &       NaN &     33.98 \\
#  693 &  8738735 &  8.09 &    A18 &       2 &      8.09 &       NaN &     12.48 &       NaN &     12.06 \\
#  694 &  8802165 & 23.15 &    A18 &       2 &     23.15 &     22.84 &     22.80 &     28.25 &     11.70 \\
#  695 &  8805348 &   NaN &    NaN &       0 &     19.65 &       NaN &     78.29 &       NaN &     21.22 \\
#  700 &  8962094 &   NaN &    NaN &       0 &     19.49 &       NaN &     30.09 &       NaN &     25.23 \\
#  701 &  9002278 & 29.90 &    A18 &       2 &     29.90 &       NaN &     35.99 &       NaN &     13.20 \\
#  703 &  9162741 &   NaN &    NaN &       0 &      5.27 &       NaN &       NaN &      4.69 &       NaN \\
#  704 &  9266431 & 20.42 &    A18 &       3 &     20.42 &     20.91 &     20.85 &     21.10 &     21.08 \\
#  707 &  9458613 &   NaN &    NaN &       1 &     21.99 &       NaN &     85.24 &       NaN &     17.86 \\
#  708 &  9530945 & 10.45 &    A18 &       2 &     10.45 &       NaN &     10.10 &       NaN &      3.36 \\
#  709 &  9578686 &   NaN &    NaN &       0 &     22.27 &       NaN &     59.69 &     29.94 &     27.95 \\
#  710 &  9590976 &   NaN &    NaN &       0 &     31.42 &       NaN &       NaN &       NaN &     15.38 \\
#  711 &  9597345 &   NaN &    NaN &       0 &     17.61 &       NaN &     35.94 &       NaN &     12.08 \\
#  714 &  9702072 & 27.70 &    A18 &       3 &     27.70 &     26.86 &     26.79 &     28.25 &     25.17 \\
#  717 &  9873254 &   NaN &    NaN &       0 &     24.94 &       NaN &     85.57 &       NaN &     48.85 \\
#  718 &  9884104 & 17.73 &    A18 &       3 &     17.73 &     17.10 &     17.36 &     17.43 &     17.36 \\
#  719 &  9950612 & 30.79 &    A18 &       3 &     30.79 &     30.79 &     30.76 &     15.30 &     30.58 \\
#  720 &  9963524 &  9.63 &    A18 &       3 &      9.63 &      9.40 &      9.43 &      9.35 &      9.37 \\
#  721 &  9964801 &   NaN &    NaN &       0 &     15.99 &       NaN &     59.42 &       NaN &     15.37 \\
#  722 &  9965439 &   NaN &    NaN &       0 &     16.26 &       NaN &      9.82 &       NaN &     18.43 \\
#  723 & 10002866 & 11.05 &    A18 &       3 &     11.05 &     10.98 &     11.07 &     11.90 &     10.98 \\
#  730 & 10227020 &   NaN &    NaN &       0 &     17.82 &       NaN &       NaN &       NaN &     18.33 \\
#  732 & 10265898 & 33.35 &    A18 &       2 &     33.35 &       NaN &     35.77 &       NaN &     16.94 \\
#  733 & 10271806 & 22.05 &    A18 &       2 &     22.05 &     21.88 &     21.88 &     20.81 &     23.00 \\
#  734 & 10272442 &   NaN &    NaN &       0 &       NaN &       NaN &     53.02 &       NaN &     18.55 \\
#  738 & 10358759 &   NaN &    NaN &       0 &       NaN &       NaN &     37.35 &       NaN &     38.32 \\
#  749 & 10601284 &   NaN &    NaN &       0 &       NaN &       NaN &     18.65 &       NaN &     14.84 \\
#  752 & 10797460 & 24.88 &    M15 &       2 &       NaN &     24.92 &     24.88 &       NaN &     22.76 \\
#  756 & 10872983 &   NaN &    NaN &       0 &       NaN &       NaN &     15.44 &       NaN &     21.71 \\
#  757 & 10910878 & 17.62 &    A18 &       3 &     17.62 &     15.94 &     16.21 &     17.43 &     15.42 \\
#  759 & 11018648 &   NaN &    NaN &       0 &     18.86 &       NaN &     24.66 &       NaN &     18.08 \\
#  760 & 11138155 &   NaN &    NaN &       0 &     21.69 &       NaN &       NaN &       NaN &     20.39 \\
#  771 & 11465813 &   NaN &    NaN &       0 &     31.89 &       NaN &       NaN &       NaN &       NaN \\
#  800 &  3342970 &   NaN &    NaN &       0 &       NaN &       NaN &     60.66 &       NaN &     36.16 \\
#  806 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  825 &  5252423 &   NaN &    NaN &       1 &     16.27 &       NaN &     35.73 &       NaN &     20.54 \\
#  829 &  5358241 &   NaN &    NaN &       0 &       NaN &       NaN &     44.14 &       NaN &     45.63 \\
#  834 &  5436502 &   NaN &    NaN &       1 &     14.07 &       NaN &     38.55 &       NaN &     13.27 \\
#  835 &  5456651 &   NaN &    NaN &       1 &     24.04 &       NaN &     29.66 &       NaN &     15.33 \\
#  837 &  5531576 & 32.21 &    M15 &       3 &       NaN &     32.40 &     32.21 &     36.49 &     31.44 \\
#  841 &  5792202 & 15.09 &    A18 &       3 &     15.09 &     14.74 &     14.89 &     14.99 &     14.77 \\
#  853 &  6428700 & 15.81 &    A18 &       3 &     15.81 &     15.77 &     15.81 &     15.95 &     15.83 \\
#  857 &  6587280 & 26.27 &    A18 &       3 &     26.27 &     26.23 &     26.31 &       NaN &     26.18 \\
#  864 &  6849310 &   NaN &    NaN &       1 &     37.21 &       NaN &     15.09 &       NaN &     13.90 \\
#  869 &  6948054 & 19.56 &    A18 &       3 &     19.56 &     19.44 &     19.60 &      9.77 &     19.87 \\
#  870 &  6949607 & 18.03 &    M15 &       3 &       NaN &     17.95 &     18.03 &     18.28 &     17.97 \\
#  872 &  7109675 & 27.83 &    M15 &       3 &       NaN &     27.86 &     27.83 &     16.29 &     13.60 \\
#  874 &  7134976 & 23.19 &    A18 &       3 &     23.19 &     23.18 &     22.95 &     24.16 &     23.22 \\
#  880 &  7366258 &   NaN &    NaN &       1 &     20.41 &       NaN &     31.26 &     28.25 &     17.13 \\
#  881 &  7373451 &   NaN &    NaN &       1 &       NaN &       NaN &     30.67 &       NaN &     15.16 \\
#  884 &  7434875 & 34.16 &    M15 &       2 &       NaN &     33.84 &     34.16 &     29.94 &     18.50 \\
#  889 &   757450 & 19.49 &    A18 &       3 &     19.49 &     19.38 &     19.40 &     18.28 &     19.21 \\
#  892 &  7678434 & 23.59 &    M13 &       3 &       NaN &     23.59 &       NaN &     20.53 &     23.85 \\
#  896 &  7825899 & 25.33 &    A18 &       3 &     25.33 &     25.07 &     24.93 &     12.29 &     24.38 \\
#  906 &  8226994 & 36.96 &    M15 &       2 &       NaN &       NaN &     36.96 &       NaN &     19.00 \\
#  907 &  8247638 &   NaN &    NaN &       1 &     19.91 &       NaN &     27.56 &     14.42 &     13.53 \\
#  918 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  921 &  8689373 &   NaN &    NaN &       1 &       NaN &       NaN &     23.98 &       NaN &     19.79 \\
#  934 &  9334289 & 25.05 &    A18 &       2 &     25.05 &     24.52 &     24.37 &     31.85 &     12.19 \\
#  935 &  9347899 &   NaN &    NaN &       1 &      9.16 &       NaN &      9.06 &       NaN &     11.37 \\
#  939 &  9466668 & 14.92 &    A18 &       2 &     14.92 &       NaN &     62.75 &       NaN &     16.34 \\
#  941 &  9480189 & 21.78 &    A18 &       3 &     21.78 &     21.68 &     21.31 &     10.56 &     21.64 \\
#  954 &  9823457 &   NaN &    NaN &       1 &     14.43 &       NaN &     57.78 &       NaN &     10.18 \\
#  958 &  1026957 & 21.01 &    D21 &       3 &       NaN &       NaN &       NaN &     10.13 &     21.01 \\
#  974 &  9414417 & 10.83 &    M15 &       3 &     24.37 &     10.85 &     10.83 &       NaN &     10.85 \\
#  975 &  3632418 & 12.58 &    A18 &       3 &     12.58 &     12.59 &     12.53 &       NaN &     12.65 \\
#  981 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
#  986 &  2854698 & 18.89 &    A18 &       3 &     18.89 &     19.20 &     19.20 &     19.21 &     19.21 \\
#  987 &  7295235 & 20.36 &    A18 &       3 &     20.36 &     20.89 &     20.51 &     19.72 &     21.13 \\
#  988 &  2302548 & 12.55 &    A18 &       3 &     12.55 &     12.37 &     12.32 &     12.29 &     12.36 \\
#  991 & 10154388 & 20.56 &    A18 &       2 &     20.56 &       NaN &     20.20 &       NaN &      9.98 \\
#  993 &  1718189 &   NaN &    NaN &       0 &       NaN &       NaN &     40.39 &       NaN &     16.91 \\
#  999 &  2165002 & 22.46 &    M15 &       3 &       NaN &     22.74 &     22.46 &     22.70 &     22.62 \\
# 1001 &  1871056 & 11.71 &    A18 &       2 &     11.71 &       NaN &     34.14 &       NaN &     11.09 \\
# 1010 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1015 &  8158127 &   NaN &    NaN &       1 &       NaN &       NaN &     69.08 &       NaN &     20.41 \\
# 1019 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1032 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1050 &  5809890 & 30.69 &    A18 &       3 &     30.69 &     29.81 &     29.97 &     27.73 &     26.92 \\
# 1052 &  5956342 &   NaN &    NaN &       1 &      8.40 &       NaN &     13.69 &       NaN &     12.17 \\
# 1054 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1060 &  5880320 &   NaN &    NaN &       1 &      7.74 &       NaN &       NaN &       NaN &      3.78 \\
# 1069 &  8222813 &   NaN &    A18 &       2 &       NaN &       NaN &       NaN &       NaN &     19.69 \\
# 1089 &  3247268 &   NaN &    NaN &       1 &     12.91 &       NaN &     49.13 &       NaN &     10.16 \\
# 1102 &  3231341 &  7.75 &    A18 &       2 &      7.75 &     10.08 &     10.08 &       NaN &      9.71 \\
# 1113 &  2854914 &   NaN &    NaN &       1 &     11.39 &       NaN &     68.28 &       NaN &     30.44 \\
# 1115 &  3116412 &   NaN &    NaN &       1 &     18.24 &       NaN &     65.62 &       NaN &     19.25 \\
# 1116 &  2849805 &   NaN &    NaN &       1 &     20.28 &       NaN &     79.99 &       NaN &     17.87 \\
# 1117 &  3114811 &   NaN &    NaN &       1 &     10.06 &       NaN &     68.53 &       NaN &     20.71 \\
# 1118 &  2853446 &   NaN &    NaN &       1 &     20.58 &       NaN &     56.98 &       NaN &     25.75 \\
# 1120 &  6307537 &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1126 &  6307521 &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1127 &  6359320 &   NaN &    NaN &       1 &     16.74 &       NaN &     39.85 &       NaN &     20.20 \\
# 1128 &  6362874 & 27.84 &    A18 &       2 &     27.84 &       NaN &     75.26 &     33.26 &     14.65 \\
# 1145 &  8313667 & 13.10 &    A18 &       3 &     13.10 &     13.00 &     12.92 &     12.09 &     12.58 \\
# 1148 &  8410727 &   NaN &    NaN &       1 &     11.07 &       NaN &     10.89 &       NaN &     10.70 \\
# 1151 &  8280511 &   NaN &    NaN &       1 &     21.63 &       NaN &     29.83 &       NaN &     10.64 \\
# 1161 & 10426656 &   NaN &    NaN &       1 &     13.82 &       NaN &     47.50 &       NaN &     14.29 \\
# 1162 & 10528068 &   NaN &    NaN &       1 &     15.05 &       NaN &     44.77 &       NaN &     10.60 \\
# 1163 & 10468940 &   NaN &    NaN &       1 &       NaN &       NaN &     28.82 &       NaN &     42.14 \\
# 1165 & 10337517 & 23.79 &    A18 &       2 &     23.79 &       NaN &     33.00 &       NaN &     11.37 \\
# 1168 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1169 & 10319385 &   NaN &    NaN &       1 &     17.19 &       NaN &     31.93 &       NaN &     14.30 \\
# 1175 & 10350571 & 16.13 &    A18 &       2 &     16.13 &       NaN &     41.62 &     41.54 &     14.90 \\
# 1196 &  3348082 &   NaN &    NaN &       1 &       NaN &       NaN &     49.36 &       NaN &      8.32 \\
# 1198 &  3447722 &   NaN &    NaN &       1 &     11.45 &       NaN &     50.44 &       NaN &     25.01 \\
# 1199 &  3859079 & 32.68 &    A18 &       2 &     32.68 &     34.26 &     34.22 &       NaN &     17.22 \\
# 1203 &  3962243 &   NaN &    NaN &       1 &       NaN &       NaN &     56.37 &       NaN &     28.72 \\
# 1206 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1215 &  3939150 &   NaN &    NaN &       1 &     24.66 &       NaN &    101.23 &       NaN &     21.43 \\
# 1216 &  3839488 & 21.29 &    A18 &       2 &     21.29 &       NaN &     21.74 &       NaN &     11.89 \\
# 1218 &  3442055 &   NaN &    NaN &       1 &     35.09 &       NaN &     57.94 &       NaN &     39.91 \\
# 1220 &  4043190 & 22.46 &    A18 &       2 &     22.46 &       NaN &     32.86 &       NaN &     18.98 \\
# 1221 &  3640905 &   NaN &    NaN &       1 &       NaN &       NaN &       NaN &       NaN &     14.34 \\
# 1222 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1230 &  6470149 &   NaN &    NaN &       1 &     15.10 &       NaN &       NaN &     43.97 &     10.35 \\
# 1239 &  6607286 &   NaN &    NaN &       1 &     13.00 &       NaN &      4.86 &       NaN &      6.72 \\
# 1240 &  6690082 &   NaN &    NaN &       1 &       NaN &       NaN &     28.15 &     14.70 &     17.30 \\
# 1241 &  6448890 &   NaN &    NaN &       1 &      1.70 &       NaN &       NaN &       NaN &     13.98 \\
# 1242 &  6607447 &   NaN &    NaN &       1 &     19.93 &       NaN &     82.98 &       NaN &     18.97 \\
# 1270 &  8564587 & 32.91 &    M15 &       2 &       NaN &     33.31 &     32.91 &     32.54 &     16.34 \\
# 1271 &  8631160 &   NaN &    NaN &       1 &     30.69 &       NaN &       NaN &       NaN &      3.95 \\
# 1274 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1275 &  8583696 &   NaN &    NaN &       1 &     21.69 &       NaN &     71.98 &       NaN &     21.48 \\
# 1276 &  8804283 &   NaN &    NaN &       1 &     30.00 &       NaN &      9.62 &       NaN &     14.69 \\
# 1278 &  8609450 &   NaN &    NaN &       1 &       NaN &       NaN &     57.60 &       NaN &     22.96 \\
# 1279 &  8628758 &   NaN &    NaN &       1 &     29.47 &       NaN &     28.75 &       NaN &     15.30 \\
# 1282 &  8822366 &   NaN &    NaN &       1 &     14.84 &       NaN &     35.53 &       NaN &     12.28 \\
# 1283 &  8700771 &   NaN &    NaN &       1 &     14.72 &       NaN &     72.66 &       NaN &     14.38 \\
# 1288 & 10790387 &   NaN &    NaN &       1 &     41.39 &       NaN &     70.84 &       NaN &      5.62 \\
# 1299 & 10864656 &   NaN &    NaN &       1 &     24.07 &       NaN &       NaN &       NaN &     17.55 \\
# 1300 & 10975146 & 39.15 &    M15 &       3 &       NaN &     38.28 &     39.15 &     29.35 &     34.05 \\
# 1301 & 10538176 &   NaN &    NaN &       1 &       NaN &       NaN &      5.68 &       NaN &     16.08 \\
# 1305 & 10730034 & 27.04 &    M15 &       3 &       NaN &     26.95 &     27.04 &       NaN &     12.60 \\
# 1306 & 10858691 &   NaN &    NaN &       1 &     16.15 &       NaN &     24.46 &       NaN &     12.09 \\
# 1307 & 10973814 & 28.13 &    M15 &       2 &       NaN &       NaN &     28.13 &       NaN &     16.31 \\
# 1308 & 10586208 &   NaN &    NaN &       1 &       NaN &       NaN &     54.99 &       NaN &     27.20 \\
# 1311 & 10713616 &   NaN &    NaN &       1 &     46.62 &       NaN &     66.30 &       NaN &     40.82 \\
# 1314 & 10585852 &   NaN &    NaN &       1 &     19.12 &       NaN &       NaN &       NaN &     20.97 \\
# 1315 & 10928043 & 11.49 &    A18 &       2 &     11.49 &       NaN &     11.17 &       NaN &     12.04 \\
# 1316 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1332 &  4455231 &   NaN &    NaN &       1 &       NaN &       NaN &     29.34 &       NaN &     13.15 \\
# 1335 &  4155328 &  4.37 &    M15 &       2 &      8.76 &       NaN &      4.37 &       NaN &      7.12 \\
# 1336 &  4077526 &   NaN &    NaN &       1 &     31.16 &       NaN &     22.87 &       NaN &     11.79 \\
# 1338 &  4466677 &   NaN &    NaN &       1 &     20.66 &       NaN &     60.45 &       NaN &     19.63 \\
# 1344 &  4136466 &   NaN &    NaN &       1 &     11.89 &       NaN &     28.50 &       NaN &      5.90 \\
# 1353 &  7303287 &  8.85 &    A18 &       3 &      8.85 &      8.65 &      8.73 &      8.96 &      8.78 \\
# 1356 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1359 &  6946199 &   NaN &    NaN &       1 &       NaN &       NaN &     56.13 &       NaN &     15.27 \\
# 1360 &  7102227 & 31.78 &    A18 &       2 &     31.78 &       NaN &     32.56 &       NaN &     15.81 \\
# 1363 &  6936909 &   NaN &    NaN &       1 &     25.18 &       NaN &     46.13 &       NaN &     21.09 \\
# 1364 &  6962977 &   NaN &    NaN &       1 &       NaN &       NaN &     62.90 &       NaN &     16.06 \\
# 1366 &  6932987 & 20.88 &    A18 &       2 &     20.88 &     31.27 &     31.19 &     32.54 &     15.63 \\
# 1367 &  6934291 & 29.89 &    A18 &       2 &     29.89 &     29.83 &     16.83 &     30.55 &     13.77 \\
# 1375 &  6766634 &   NaN &    NaN &       1 &     16.33 &       NaN &     75.76 &       NaN &     16.86 \\
# 1378 &  7375795 &   NaN &    NaN &       0 &       NaN &       NaN &     34.91 &       NaN &       NaN \\
# 1379 &  7211221 &   NaN &    NaN &       1 &     21.75 &       NaN &     56.24 &       NaN &     17.69 \\
# 1396 &  9455556 & 24.86 &    A18 &       3 &     24.86 &     24.37 &     24.38 &     34.01 &     24.49 \\
# 1411 &  9425139 &   NaN &    NaN &       1 &     10.82 &       NaN &    104.13 &       NaN &     30.84 \\
# 1412 &  8950853 &   NaN &    NaN &       1 &     11.74 &       NaN &     11.15 &       NaN &     16.28 \\
# 1413 &  9006449 &   NaN &    NaN &       1 &       NaN &       NaN &     31.50 &     26.74 &     13.42 \\
# 1421 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 1426 & 11122894 & 23.75 &    A18 &       2 &     23.75 &       NaN &     33.22 &       NaN &     22.07 \\
# 1428 & 11401182 &   NaN &    NaN &       1 &     16.37 &       NaN &     39.94 &       NaN &     17.42 \\
# 1431 & 11075279 & 29.78 &    A18 &       2 &     29.78 &       NaN &     29.38 &       NaN &     14.97 \\
# 1432 & 11014932 &   NaN &    NaN &       1 &     64.40 &       NaN &     54.29 &       NaN &     17.04 \\
# 1436 & 11389771 & 23.80 &    A18 &       2 &     23.80 &     22.69 &     22.66 &     20.81 &     21.56 \\
# ...
# 4298 &  2852941 & 35.55 &    D21 &       2 &       NaN &       NaN &       NaN &       NaN &     35.55 \\
# 4301 &  8773015 &   NaN &    NaN &       1 &     35.19 &       NaN &     68.08 &       NaN &     28.74 \\
# 4302 &  6290935 &   NaN &    NaN &       1 &       NaN &       NaN &     68.39 &       NaN &     11.08 \\
# 4304 & 11612280 &   NaN &    NaN &       1 &     23.44 &       NaN &     43.16 &       NaN &     22.27 \\
# 4312 & 10722485 &   NaN &    NaN &       1 &       NaN &       NaN &     74.39 &       NaN &     17.52 \\
# 4318 &  9286088 &  2.34 &    M15 &       2 &     24.45 &       NaN &      2.34 &       NaN &      2.31 \\
# 4323 &  5385410 &   NaN &    NaN &       1 &     26.94 &       NaN &     52.58 &       NaN &     22.25 \\
# 4329 & 12456063 &  7.49 &    A18 &       3 &      7.49 &       NaN &      7.05 &       NaN &      6.96 \\
# 4335 & 10730070 & 32.26 &    M15 &       2 &     38.10 &       NaN &     32.26 &       NaN &     16.08 \\
# 4356 &  8459663 & 12.18 &    M15 &       3 &       NaN &       NaN &     12.18 &       NaN &     12.17 \\
# 4366 & 10647452 & 38.99 &    A18 &       2 &     38.99 &       NaN &     38.17 &       NaN &     19.48 \\
# 4367 &  4773392 &  9.65 &    A18 &       2 &      9.65 &       NaN &     27.32 &       NaN &      8.95 \\
# 4368 &  5471489 &   NaN &    NaN &       1 &       NaN &       NaN &       NaN &       NaN &      6.22 \\
# 4374 & 10991114 &   NaN &    NaN &       1 &     33.38 &       NaN &     23.80 &       NaN &     10.88 \\
# 4382 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4383 &  9883606 & 14.21 &    A18 &       3 &     14.21 &       NaN &     14.22 &       NaN &     14.24 \\
# 4385 &  3645438 &   NaN &    NaN &       1 &     18.74 &       NaN &     46.13 &       NaN &     18.73 \\
# 4399 &  8345384 & 17.73 &    A18 &       3 &     17.73 &       NaN &     17.56 &       NaN &     17.41 \\
# 4400 &  2831055 & 21.99 &    A18 &       3 &     21.99 &       NaN &     21.92 &       NaN &     10.94 \\
# 4407 &  8396660 & 19.41 &    A18 &       3 &     19.41 &       NaN &     20.08 &       NaN &     10.05 \\
# 4409 &  5308537 & 23.92 &    A18 &       2 &     23.92 &       NaN &     19.08 &       NaN &     19.10 \\
# 4411 &  5281113 & 11.85 &    A18 &       3 &     11.85 &       NaN &     11.66 &       NaN &     13.25 \\
# 4421 &  9836563 &   NaN &    NaN &       1 &     23.18 &       NaN &     27.74 &       NaN &     23.89 \\
# 4423 &  3866536 &   NaN &    NaN &       0 &      7.65 &       NaN &      7.64 &       NaN &       NaN \\
# 4426 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4430 &  9642018 &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4431 &  9936080 &  9.90 &    A18 &       2 &      9.90 &       NaN &     52.81 &       NaN &      8.24 \\
# 4435 &  8278685 & 10.37 &    A18 &       2 &     10.37 &       NaN &     31.27 &       NaN &     10.50 \\
# 4441 &  8416523 &   NaN &    A18 &       2 &       NaN &       NaN &       NaN &       NaN &     19.51 \\
# 4443 &  5780855 &  7.43 &    M15 &       2 &     20.60 &       NaN &      7.43 &       NaN &      8.65 \\
# 4446 & 10329196 &   NaN &    NaN &       1 &     18.73 &       NaN &       NaN &       NaN &     20.45 \\
# 4452 &  4474462 &   NaN &    NaN &       1 &     20.61 &       NaN &     19.61 &       NaN &     35.31 \\
# 4457 & 12109267 & 13.01 &    A18 &       2 &     13.01 &       NaN &     75.19 &       NaN &     12.46 \\
# 4469 & 10006641 &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4473 &  7133294 & 16.37 &    A18 &       3 &     16.37 &       NaN &     16.81 &       NaN &     17.11 \\
# 4480 & 10467714 & 20.31 &    D21 &       2 &      5.53 &       NaN &     10.41 &       NaN &     20.31 \\
# 4482 &  7778427 &  6.70 &    A18 &       2 &      6.70 &       NaN &     70.96 &       NaN &      6.53 \\
# 4505 &  8493354 & 10.01 &    M15 &       2 &     21.41 &       NaN &     10.01 &       NaN &      5.15 \\
# 4546 &  5033823 &   NaN &    NaN &       1 &     40.45 &       NaN &     55.37 &       NaN &     46.57 \\
# 4556 & 10399321 &   NaN &    NaN &       0 &     27.07 &       NaN &     57.57 &       NaN &       NaN \\
# 4557 & 10257229 &   NaN &    NaN &       1 &       NaN &       NaN &     68.71 &       NaN &     24.82 \\
# 4561 &  7747457 &   NaN &    NaN &       1 &       NaN &       NaN &      0.90 &       NaN &     11.74 \\
# 4567 &  8332521 &  5.79 &    A18 &       2 &      5.79 &       NaN &      5.37 &       NaN &      5.51 \\
# 4575 &  9893468 & 12.01 &    A18 &       2 &     12.01 &       NaN &     72.98 &       NaN &     11.59 \\
# 4580 &  8628761 &   NaN &    NaN &       1 &     34.39 &       NaN &     79.13 &       NaN &     14.49 \\
# 4581 &  2572029 &   NaN &    NaN &       1 &     23.87 &       NaN &     74.07 &       NaN &     30.54 \\
# 4582 &  7905106 & 14.44 &    A18 &       2 &     14.44 &       NaN &     31.85 &       NaN &     13.13 \\
# 4585 &  9009036 &  9.69 &    A18 &       2 &      9.69 &       NaN &      9.37 &       NaN &      9.45 \\
# 4588 &  8806985 & 13.67 &    A18 &       3 &     13.67 &       NaN &     13.43 &       NaN &     13.63 \\
# 4601 & 11153476 &  8.82 &    D21 &       2 &       NaN &       NaN &     17.02 &       NaN &      8.82 \\
# 4603 &  8430053 &   NaN &    NaN &       1 &     18.07 &       NaN &     81.70 &       NaN &      8.93 \\
# 4605 & 12458605 &   NaN &    NaN &       1 &     17.61 &       NaN &     77.75 &       NaN &     23.32 \\
# 4613 & 10220837 & 26.47 &    A18 &       3 &     26.47 &       NaN &     24.84 &       NaN &     24.53 \\
# 4614 &  7583650 &   NaN &    NaN &       1 &     26.81 &       NaN &     27.70 &       NaN &     11.38 \\
# 4617 &  9701962 &   NaN &    NaN &       1 &      1.10 &       NaN &     48.32 &       NaN &     40.92 \\
# 4633 &  5954001 & 14.86 &    A18 &       2 &     14.86 &       NaN &     15.20 &       NaN &     16.11 \\
# 4637 &  9457728 & 20.51 &    A18 &       3 &     20.51 &       NaN &     20.07 &       NaN &     21.60 \\
# 4640 &  9412623 & 11.42 &    A18 &       2 &     11.42 &       NaN &       NaN &       NaN &      6.29 \\
# 4647 &  9947653 & 43.64 &    A18 &       2 &     43.64 &       NaN &     53.14 &       NaN &     19.85 \\
# 4651 &  6717252 & 16.76 &    A18 &       3 &     16.76 &       NaN &     16.46 &       NaN &     16.89 \\
# 4653 & 11181260 &  8.43 &    A18 &       2 &      8.43 &       NaN &     45.14 &       NaN &      9.05 \\
# 4657 &  6527078 & 17.05 &    D21 &       2 &     29.63 &       NaN &     77.22 &       NaN &     17.05 \\
# 4659 &  2857607 & 24.22 &    A18 &       2 &     24.22 &       NaN &     23.94 &       NaN &     12.12 \\
# 4663 &  7515336 &   NaN &    NaN &       1 &       NaN &       NaN &     52.37 &       NaN &     16.14 \\
# 4665 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4674 &  6839010 &   NaN &    NaN &       1 &     24.25 &       NaN &     50.35 &       NaN &     15.64 \\
# 4686 &  5819801 & 34.38 &    A18 &       2 &     34.38 &       NaN &     36.03 &       NaN &     12.81 \\
# 4693 &  8417078 &   NaN &    NaN &       1 &     20.86 &       NaN &     27.20 &       NaN &     21.68 \\
# 4699 &  7891294 & 10.56 &    A18 &       2 &     10.56 &       NaN &     10.40 &       NaN &     11.03 \\
# 4715 &  6264750 & 12.84 &    A18 &       2 &     12.84 &       NaN &     58.28 &       NaN &     11.75 \\
# 4716 & 11290515 & 14.87 &    M15 &       2 &       NaN &       NaN &     14.87 &       NaN &     14.01 \\
# 4717 &  4902202 &   NaN &    NaN &       0 &     14.30 &       NaN &     35.57 &       NaN &       NaN \\
# 4725 &  7778621 & 26.86 &    A18 &       2 &     26.86 &       NaN &     42.21 &       NaN &     20.22 \\
# 4744 &  5709906 &   NaN &    NaN &       1 &     23.03 &       NaN &     52.88 &       NaN &     24.22 \\
# 4745 & 11757451 &   NaN &    NaN &       1 &     16.83 &       NaN &     46.71 &       NaN &     16.68 \\
# 4763 &  8349399 &   NaN &    NaN &       1 &     12.69 &       NaN &     32.02 &       NaN &     11.55 \\
# 4765 & 10615440 &  8.75 &    A18 &       2 &      8.75 &       NaN &      8.51 &       NaN &      8.47 \\
# 4771 & 11658036 &   NaN &    NaN &       1 &     24.87 &       NaN &     64.63 &       NaN &      6.48 \\
# 4773 &  7906892 & 18.77 &    A18 &       2 &     18.77 &       NaN &     19.20 &       NaN &     18.97 \\
# 4774 &  4277304 & 31.32 &    A18 &       2 &     31.32 &       NaN &     30.73 &       NaN &     30.27 \\
# 4775 &  8626325 &   NaN &    NaN &       1 &     20.39 &       NaN &    125.65 &       NaN &     37.56 \\
# 4792 & 11618569 & 16.41 &    A18 &       2 &     16.41 &       NaN &     16.13 &       NaN &      7.96 \\
# 4811 &  8811490 & 17.94 &    A18 &       3 &     17.94 &       NaN &     16.59 &       NaN &     16.44 \\
# 4822 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4829 & 12401132 &   NaN &    NaN &       1 &       NaN &       NaN &      0.30 &       NaN &     19.25 \\
# 4833 & 10584140 &   NaN &    NaN &       1 &     10.34 &       NaN &     73.61 &       NaN &     17.40 \\
# 4834 &  8233326 &   NaN &    NaN &       1 &       NaN &       NaN &       NaN &       NaN &     36.91 \\
# 4839 &  9110610 &   NaN &    NaN &       1 &     27.93 &       NaN &     78.85 &       NaN &     35.00 \\
# 4841 &  5480884 &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4850 &  6786224 & 17.33 &    A18 &       2 &     17.33 &       NaN &     24.96 &       NaN &     14.85 \\
# 4864 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4887 &  4059887 &   NaN &    NaN &       0 &     19.52 &       NaN &     19.47 &       NaN &       NaN \\
# 4892 & 10586744 &   NaN &    NaN &       1 &       NaN &       NaN &     51.84 &       NaN &     19.43 \\
# 4898 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4907 &  5437762 &   NaN &    NaN &       1 &     16.81 &       NaN &     23.26 &       NaN &     17.47 \\
# 4961 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 4978 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5018 &  3854101 &   NaN &    NaN &       0 &     18.73 &       NaN &     20.43 &       NaN &       NaN \\
# 5021 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5039 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5048 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5057 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5084 &  4760478 &   NaN &    NaN &       1 &      8.01 &       NaN &     27.41 &       NaN &     17.63 \\
# 5085 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5107 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5119 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5124 &  5094412 &   NaN &    NaN &       0 &       NaN &       NaN &     19.02 &       NaN &       NaN \\
# 5135 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5155 &  5374838 &   NaN &    NaN &       1 &       NaN &       NaN &     38.94 &       NaN &     17.51 \\
# 5159 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5198 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5216 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5236 &  6067545 &   NaN &    NaN &       0 &       NaN &       NaN &     12.50 &       NaN &       NaN \\
# 5241 &  6139220 &   NaN &    NaN &       0 &     22.86 &       NaN &     63.22 &       NaN &       NaN \\
# 5247 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5269 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5278 &  6372194 &   NaN &    NaN &       1 &       NaN &       NaN &     43.04 &       NaN &     17.96 \\
# 5284 &  6443093 &   NaN &    NaN &       1 &       NaN &       NaN &     79.11 &       NaN &     17.27 \\
# 5290 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5324 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5375 &  7213311 &   NaN &    NaN &       1 &       NaN &       NaN &       NaN &       NaN &     17.18 \\
# 5379 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5380 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5393 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5423 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5546 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5567 &  8742270 &   NaN &    NaN &       0 &     46.42 &       NaN &       NaN &       NaN &       NaN \\
# 5592 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5612 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5613 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5622 &  9141355 &   NaN &    NaN &       1 &       NaN &       NaN &     36.55 &       NaN &     13.03 \\
# 5626 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5645 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5689 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5702 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5706 &  9715631 &   NaN &    NaN &       1 &       NaN &       NaN &     78.77 &       NaN &     10.54 \\
# 5782 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5790 & 10394802 &   NaN &    NaN &       1 &       NaN &       NaN &     27.67 &       NaN &     28.26 \\
# 5798 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5837 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5850 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5852 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5855 & 11036168 &   NaN &    NaN &       1 &     18.34 &       NaN &     25.02 &       NaN &     12.90 \\
# 5877 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5888 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5900 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5929 & 11716643 & 37.72 &    M15 &       2 &       NaN &       NaN &     37.72 &       NaN &     14.71 \\
# 5949 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 5953 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# 6102 &     <NA> &   NaN &    NaN &       0 &       NaN &       NaN &       NaN &       NaN &       NaN \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### Save the rotation period table

# %%
prot_table.to_csv("../data/table1.csv")

# %% [markdown]
# #### Save the merged CKS table

# %%
cks.to_parquet('../data/cks-merged.parquet')
